# %% [markdown]
# 3. Библиотека requests

# %%
import requests # Импортируем библиотеку requests
url = 'https://www.cbr-xml-daily.ru/daily_json.js' # Определяем значение URL страницы для запроса
response = requests.get(url) # Делаем GET-запрос к ресурсу и результат ответа сохраняем в переменной response

# %%
print(response) # Выводим значение response на экран как объект
# Out:
# <Response [200]>

# %%
print(response.status_code) # Выводим числовое значение response на экран
# Out:
# 200

# %%
print(response.text) # Выводим содержимое атрибута text переменной response на экран
# Out:
# {
#     "Date": "2022-02-12T11:30:00+03:00",
#     "PreviousDate": "2022-02-11T11:30:00+03:00",
#     "PreviousURL": "\/\/www.cbr-xml-daily.ru\/archive\/2022\/02\/11\/daily_json.js",
#     "Timestamp": "2022-02-13T23:00:00+03:00",
#     "Valute": {
#         "AUD": {
#             "ID": "R01010",
#             "NumCode": "036",
#             "CharCode": "AUD",
#             "Nominal": 1,
#             "Name": "Австралийский доллар",
#             "Value": 53.5105,
#             "Previous": 53.7266
#         },
#         "AZN": {
#             "ID": "R01020A",
#             "NumCode": "944",
#             "CharCode": "AZN",
#             "Nominal": 1,
#             "Name": "Азербайджанский манат",
#             "Value": 44.1358,
#             "Previous": 43.9812
#         },
#         "GBP": {
#             "ID": "R01035",
#             "NumCode": "826",
#             "CharCode": "GBP",
#             "Nominal": 1,
#             "Name": "Фунт стерлингов Соединенного королевства",
#             "Value": 101.6295,
#             "Previous": 101.2736
#         },
#         "AMD": {
#             "ID": "R01060",
#             "NumCode": "051",
#             "CharCode": "AMD",
#             "Nominal": 100,
#             "Name": "Армянских драмов",
#             "Value": 15.6125,
#             "Previous": 15.5481
#         },
#         "BYN": {
#             "ID": "R01090B",
#             "NumCode": "933",
#             "CharCode": "BYN",
#             "Nominal": 1,
#             "Name": "Белорусский рубль",
#             "Value": 29.3502,
#             "Previous": 29.2108
#         },
#         "BGN": {
#             "ID": "R01100",
#             "NumCode": "975",
#             "CharCode": "BGN",
#             "Nominal": 1,
#             "Name": "Болгарский лев",
#             "Value": 43.6833,
#             "Previous": 43.6677
#         },
#         "BRL": {
#             "ID": "R01115",
#             "NumCode": "986",
#             "CharCode": "BRL",
#             "Nominal": 1,
#             "Name": "Бразильский реал",
#             "Value": 14.2829,
#             "Previous": 14.2715
#         },
#         "HUF": {
#             "ID": "R01135",
#             "NumCode": "348",
#             "CharCode": "HUF",
#             "Nominal": 100,
#             "Name": "Венгерских форинтов",
#             "Value": 24.1247,
#             "Previous": 24.2143
#         },
#         "HKD": {
#             "ID": "R01200",
#             "NumCode": "344",
#             "CharCode": "HKD",
#             "Nominal": 10,
#             "Name": "Гонконгских долларов",
#             "Value": 96.0949,
#             "Previous": 95.88
#         },
#         "DKK": {
#             "ID": "R01215",
#             "NumCode": "208",
#             "CharCode": "DKK",
#             "Nominal": 1,
#             "Name": "Датская крона",
#             "Value": 11.4834,
#             "Previous": 11.4764
#         },
#         "USD": {
#             "ID": "R01235",
#             "NumCode": "840",
#             "CharCode": "USD",
#             "Nominal": 1,
#             "Name": "Доллар США",
#             "Value": 74.9867,
#             "Previous": 74.7241
#         },
#         "EUR": {
#             "ID": "R01239",
#             "NumCode": "978",
#             "CharCode": "EUR",
#             "Nominal": 1,
#             "Name": "Евро",
#             "Value": 85.3574,
#             "Previous": 85.3798
#         },
#         "INR": {
#             "ID": "R01270",
#             "NumCode": "356",
#             "CharCode": "INR",
#             "Nominal": 100,
#             "Name": "Индийских рупий",
#             "Value": 99.5839,
#             "Previous": 99.6169
#         },
#         "KZT": {
#             "ID": "R01335",
#             "NumCode": "398",
#             "CharCode": "KZT",
#             "Nominal": 100,
#             "Name": "Казахстанских тенге",
#             "Value": 17.4631,
#             "Previous": 17.5018
#         },
#         "CAD": {
#             "ID": "R01350",
#             "NumCode": "124",
#             "CharCode": "CAD",
#             "Nominal": 1,
#             "Name": "Канадский доллар",
#             "Value": 58.9333,
#             "Previous": 58.9632
#         },
#         "KGS": {
#             "ID": "R01370",
#             "NumCode": "417",
#             "CharCode": "KGS",
#             "Nominal": 100,
#             "Name": "Киргизских сомов",
#             "Value": 88.3994,
#             "Previous": 88.0898
#         },
#         "CNY": {
#             "ID": "R01375",
#             "NumCode": "156",
#             "CharCode": "CNY",
#             "Nominal": 1,
#             "Name": "Китайский юань",
#             "Value": 11.7915,
#             "Previous": 11.7502
#         },
#         "MDL": {
#             "ID": "R01500",
#             "NumCode": "498",
#             "CharCode": "MDL",
#             "Nominal": 10,
#             "Name": "Молдавских леев",
#             "Value": 42.1274,
#             "Previous": 41.8625
#         },
#         "NOK": {
#             "ID": "R01535",
#             "NumCode": "578",
#             "CharCode": "NOK",
#             "Nominal": 10,
#             "Name": "Норвежских крон",
#             "Value": 84.9486,
#             "Previous": 84.8308
#         },
#         "PLN": {
#             "ID": "R01565",
#             "NumCode": "985",
#             "CharCode": "PLN",
#             "Nominal": 1,
#             "Name": "Польский злотый",
#             "Value": 18.9112,
#             "Previous": 19.0273
#         },
#         "RON": {
#             "ID": "R01585F",
#             "NumCode": "946",
#             "CharCode": "RON",
#             "Nominal": 1,
#             "Name": "Румынский лей",
#             "Value": 17.2776,
#             "Previous": 17.2729
#         },
#         "XDR": {
#             "ID": "R01589",
#             "NumCode": "960",
#             "CharCode": "XDR",
#             "Nominal": 1,
#             "Name": "СДР (специальные права заимствования)",
#             "Value": 105.2753,
#             "Previous": 104.9134
#         },
#         "SGD": {
#             "ID": "R01625",
#             "NumCode": "702",
#             "CharCode": "SGD",
#             "Nominal": 1,
#             "Name": "Сингапурский доллар",
#             "Value": 55.7646,
#             "Previous": 55.6936
#         },
#         "TJS": {
#             "ID": "R01670",
#             "NumCode": "972",
#             "CharCode": "TJS",
#             "Nominal": 10,
#             "Name": "Таджикских сомони",
#             "Value": 66.3893,
#             "Previous": 66.1568
#         },
#         "TRY": {
#             "ID": "R01700J",
#             "NumCode": "949",
#             "CharCode": "TRY",
#             "Nominal": 10,
#             "Name": "Турецких лир",
#             "Value": 55.3865,
#             "Previous": 55.1771
#         },
#         "TMT": {
#             "ID": "R01710A",
#             "NumCode": "934",
#             "CharCode": "TMT",
#             "Nominal": 1,
#             "Name": "Новый туркменский манат",
#             "Value": 21.4554,
#             "Previous": 21.3803
#         },
#         "UZS": {
#             "ID": "R01717",
#             "NumCode": "860",
#             "CharCode": "UZS",
#             "Nominal": 10000,
#             "Name": "Узбекских сумов",
#             "Value": 69.1043,
#             "Previous": 68.9655
#         },
#         "UAH": {
#             "ID": "R01720",
#             "NumCode": "980",
#             "CharCode": "UAH",
#             "Nominal": 10,
#             "Name": "Украинских гривен",
#             "Value": 26.7511,
#             "Previous": 26.783
#         },
#         "CZK": {
#             "ID": "R01760",
#             "NumCode": "203",
#             "CharCode": "CZK",
#             "Nominal": 10,
#             "Name": "Чешских крон",
#             "Value": 35.0618,
#             "Previous": 35.0924
#         },
#         "SEK": {
#             "ID": "R01770",
#             "NumCode": "752",
#             "CharCode": "SEK",
#             "Nominal": 10,
#             "Name": "Шведских крон",
#             "Value": 80.8029,
#             "Previous": 82.1243
#         },
#         "CHF": {
#             "ID": "R01775",
#             "NumCode": "756",
#             "CharCode": "CHF",
#             "Nominal": 1,
#             "Name": "Швейцарский франк",
#             "Value": 80.9093,
#             "Previous": 80.8702
#         },
#         "ZAR": {
#             "ID": "R01810",
#             "NumCode": "710",
#             "CharCode": "ZAR",
#             "Nominal": 10,
#             "Name": "Южноафриканских рэндов",
#             "Value": 49.6597,
#             "Previous": 49.3424
#         },
#         "KRW": {
#             "ID": "R01815",
#             "NumCode": "410",
#             "CharCode": "KRW",
#             "Nominal": 1000,
#             "Name": "Вон Республики Корея",
#             "Value": 62.7039,
#             "Previous": 62.5126
#         },
#         "JPY": {
#             "ID": "R01820",
#             "NumCode": "392",
#             "CharCode": "JPY",
#             "Nominal": 100,
#             "Name": "Японских иен",
#             "Value": 64.6326,
#             "Previous": 64.6402
#         }
#     }
# }

# %%
type(response.text)
# Out:
# str

# %%
from pprint import pprint # Импортируем функцию pprint()
currencies = response.json() # Применяем метод json()
pprint(currencies) # Выводим результат на экран)
# Out:
# {'Date': '2022-02-12T11:30:00+03:00',
#  'PreviousDate': '2022-02-11T11:30:00+03:00',
#  'PreviousURL': '//www.cbr-xml-daily.ru/archive/2022/02/11/daily_json.js',
#  'Timestamp': '2022-02-13T23:00:00+03:00',
#  'Valute': {'AMD': {'CharCode': 'AMD',
#                     'ID': 'R01060',
#                     'Name': 'Армянских драмов',
#                     'Nominal': 100,
#                     'NumCode': '051',
#                     'Previous': 15.5481,
#                     'Value': 15.6125},
#             'AUD': {'CharCode': 'AUD',
#                     'ID': 'R01010',
#                     'Name': 'Австралийский доллар',
#                     'Nominal': 1,
#                     'NumCode': '036',
#                     'Previous': 53.7266,
#                     'Value': 53.5105},
#             'AZN': {'CharCode': 'AZN',
#                     'ID': 'R01020A',
#                     'Name': 'Азербайджанский манат',
#                     'Nominal': 1,
#                     'NumCode': '944',
#                     'Previous': 43.9812,
#                     'Value': 44.1358},
#             'BGN': {'CharCode': 'BGN',
#                     'ID': 'R01100',
#                     'Name': 'Болгарский лев',
#                     'Nominal': 1,
#                     'NumCode': '975',
#                     'Previous': 43.6677,
#                     'Value': 43.6833},
#             'BRL': {'CharCode': 'BRL',
#                     'ID': 'R01115',
#                     'Name': 'Бразильский реал',
#                     'Nominal': 1,
#                     'NumCode': '986',
#                     'Previous': 14.2715,
#                     'Value': 14.2829},
#             'BYN': {'CharCode': 'BYN',
#                     'ID': 'R01090B',
#                     'Name': 'Белорусский рубль',
#                     'Nominal': 1,
#                     'NumCode': '933',
#                     'Previous': 29.2108,
#                     'Value': 29.3502},
#             'CAD': {'CharCode': 'CAD',
#                     'ID': 'R01350',
#                     'Name': 'Канадский доллар',
#                     'Nominal': 1,
#                     'NumCode': '124',
#                     'Previous': 58.9632,
#                     'Value': 58.9333},
#             'CHF': {'CharCode': 'CHF',
#                     'ID': 'R01775',
#                     'Name': 'Швейцарский франк',
#                     'Nominal': 1,
#                     'NumCode': '756',
#                     'Previous': 80.8702,
#                     'Value': 80.9093},
#             'CNY': {'CharCode': 'CNY',
#                     'ID': 'R01375',
#                     'Name': 'Китайский юань',
#                     'Nominal': 1,
#                     'NumCode': '156',
#                     'Previous': 11.7502,
#                     'Value': 11.7915},
#             'CZK': {'CharCode': 'CZK',
#                     'ID': 'R01760',
#                     'Name': 'Чешских крон',
#                     'Nominal': 10,
#                     'NumCode': '203',
#                     'Previous': 35.0924,
#                     'Value': 35.0618},
#             'DKK': {'CharCode': 'DKK',
#                     'ID': 'R01215',
#                     'Name': 'Датская крона',
#                     'Nominal': 1,
#                     'NumCode': '208',
#                     'Previous': 11.4764,
#                     'Value': 11.4834},
#             'EUR': {'CharCode': 'EUR',
#                     'ID': 'R01239',
#                     'Name': 'Евро',
#                     'Nominal': 1,
#                     'NumCode': '978',
#                     'Previous': 85.3798,
#                     'Value': 85.3574},
#             'GBP': {'CharCode': 'GBP',
#                     'ID': 'R01035',
#                     'Name': 'Фунт стерлингов Соединенного королевства',
#                     'Nominal': 1,
#                     'NumCode': '826',
#                     'Previous': 101.2736,
#                     'Value': 101.6295},
#             'HKD': {'CharCode': 'HKD',
#                     'ID': 'R01200',
#                     'Name': 'Гонконгских долларов',
#                     'Nominal': 10,
#                     'NumCode': '344',
#                     'Previous': 95.88,
#                     'Value': 96.0949},
#             'HUF': {'CharCode': 'HUF',
#                     'ID': 'R01135',
#                     'Name': 'Венгерских форинтов',
#                     'Nominal': 100,
#                     'NumCode': '348',
#                     'Previous': 24.2143,
#                     'Value': 24.1247},
#             'INR': {'CharCode': 'INR',
#                     'ID': 'R01270',
#                     'Name': 'Индийских рупий',
#                     'Nominal': 100,
#                     'NumCode': '356',
#                     'Previous': 99.6169,
#                     'Value': 99.5839},
#             'JPY': {'CharCode': 'JPY',
#                     'ID': 'R01820',
#                     'Name': 'Японских иен',
#                     'Nominal': 100,
#                     'NumCode': '392',
#                     'Previous': 64.6402,
#                     'Value': 64.6326},
#             'KGS': {'CharCode': 'KGS',
#                     'ID': 'R01370',
#                     'Name': 'Киргизских сомов',
#                     'Nominal': 100,
#                     'NumCode': '417',
#                     'Previous': 88.0898,
#                     'Value': 88.3994},
#             'KRW': {'CharCode': 'KRW',
#                     'ID': 'R01815',
#                     'Name': 'Вон Республики Корея',
#                     'Nominal': 1000,
#                     'NumCode': '410',
#                     'Previous': 62.5126,
#                     'Value': 62.7039},
#             'KZT': {'CharCode': 'KZT',
#                     'ID': 'R01335',
#                     'Name': 'Казахстанских тенге',
#                     'Nominal': 100,
#                     'NumCode': '398',
#                     'Previous': 17.5018,
#                     'Value': 17.4631},
#             'MDL': {'CharCode': 'MDL',
#                     'ID': 'R01500',
#                     'Name': 'Молдавских леев',
#                     'Nominal': 10,
#                     'NumCode': '498',
#                     'Previous': 41.8625,
#                     'Value': 42.1274},
#             'NOK': {'CharCode': 'NOK',
#                     'ID': 'R01535',
#                     'Name': 'Норвежских крон',
#                     'Nominal': 10,
#                     'NumCode': '578',
#                     'Previous': 84.8308,
#                     'Value': 84.9486},
#             'PLN': {'CharCode': 'PLN',
#                     'ID': 'R01565',
#                     'Name': 'Польский злотый',
#                     'Nominal': 1,
#                     'NumCode': '985',
#                     'Previous': 19.0273,
#                     'Value': 18.9112},
#             'RON': {'CharCode': 'RON',
#                     'ID': 'R01585F',
#                     'Name': 'Румынский лей',
#                     'Nominal': 1,
#                     'NumCode': '946',
#                     'Previous': 17.2729,
#                     'Value': 17.2776},
#             'SEK': {'CharCode': 'SEK',
#                     'ID': 'R01770',
#                     'Name': 'Шведских крон',
#                     'Nominal': 10,
#                     'NumCode': '752',
#                     'Previous': 82.1243,
#                     'Value': 80.8029},
#             'SGD': {'CharCode': 'SGD',
#                     'ID': 'R01625',
#                     'Name': 'Сингапурский доллар',
#                     'Nominal': 1,
#                     'NumCode': '702',
#                     'Previous': 55.6936,
#                     'Value': 55.7646},
#             'TJS': {'CharCode': 'TJS',
#                     'ID': 'R01670',
#                     'Name': 'Таджикских сомони',
#                     'Nominal': 10,
#                     'NumCode': '972',
#                     'Previous': 66.1568,
#                     'Value': 66.3893},
#             'TMT': {'CharCode': 'TMT',
#                     'ID': 'R01710A',
#                     'Name': 'Новый туркменский манат',
#                     'Nominal': 1,
#                     'NumCode': '934',
#                     'Previous': 21.3803,
#                     'Value': 21.4554},
#             'TRY': {'CharCode': 'TRY',
#                     'ID': 'R01700J',
#                     'Name': 'Турецких лир',
#                     'Nominal': 10,
#                     'NumCode': '949',
#                     'Previous': 55.1771,
#                     'Value': 55.3865},
#             'UAH': {'CharCode': 'UAH',
#                     'ID': 'R01720',
#                     'Name': 'Украинских гривен',
#                     'Nominal': 10,
#                     'NumCode': '980',
#                     'Previous': 26.783,
#                     'Value': 26.7511},
#             'USD': {'CharCode': 'USD',
#                     'ID': 'R01235',
#                     'Name': 'Доллар США',
#                     'Nominal': 1,
#                     'NumCode': '840',
#                     'Previous': 74.7241,
#                     'Value': 74.9867},
#             'UZS': {'CharCode': 'UZS',
#                     'ID': 'R01717',
#                     'Name': 'Узбекских сумов',
#                     'Nominal': 10000,
#                     'NumCode': '860',
#                     'Previous': 68.9655,
#                     'Value': 69.1043},
#             'XDR': {'CharCode': 'XDR',
#                     'ID': 'R01589',
#                     'Name': 'СДР (специальные права заимствования)',
#                     'Nominal': 1,
#                     'NumCode': '960',
#                     'Previous': 104.9134,
#                     'Value': 105.2753},
#             'ZAR': {'CharCode': 'ZAR',
#                     'ID': 'R01810',
#                     'Name': 'Южноафриканских рэндов',
#                     'Nominal': 10,
#                     'NumCode': '710',
#                     'Previous': 49.3424,
#                     'Value': 49.6597}}}

# %%
type(currencies)
# Out:
# dict

# %%
pprint(currencies['Valute']['EUR']) # Выводим на экран информацию о валюте евро
# Out:
# {'CharCode': 'EUR',
#  'ID': 'R01239',
#  'Name': 'Евро',
#  'Nominal': 1,
#  'NumCode': '978',
#  'Previous': 85.3798,
#  'Value': 85.3574}

# %%
print(currencies['Valute']['CZK']['Name'])
# Out:
# Чешских крон

# %% [markdown]
# ПОЛУЧАЕМ СОДЕРЖИМОЕ ВЕБ-СТРАНИЦЫ

# %%
import requests # Импортируем библиотеку requests
url = 'https://nplus1.ru/news/2021/10/11/econobel2021' # Определяем адрес страницы
response = requests.get(url)  # Выполняем GET-запрос
print(response.text)  # Выводим содержимое атрибута text
# Out:
# <!doctype html>
# <html class="no-js bg-fixed _no-bg" style="background-image:url(https://nplus1.ru/images/2021/10/11/9c6bcb5f7c01c6d88d49410e16ebc003.jpg)" lang="">
# <head>
#
#     <meta charset="utf-8">
#     <meta http-equiv="x-ua-compatible" content="ie=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#         <meta name="apple-mobile-web-app-capable" content="yes">
#     <meta name="apple-mobile-web-app-status-bar-style" content="black">
#                 <meta name='wmail-verification' content='7991d7eb02d759f05b9050e111a7e3eb' />
#
#     <link rel="canonical" href="https://nplus1.ru/news/2021/10/11/econobel2021" />
#
#         <title>Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей</title>
#
#     	    <meta itemprop="datePublished" content="2021-10-11"/>
#
# 	    <meta name="mediator_author" content="Илья Ферапонтов"/>
#
#         <!-- amp page -->
#     <link rel="amphtml" href="https://nplus1.ru/news/2021/10/11/econobel2021/amp">
#
#
#         <!-- for Google -->
#         <meta name="description" content="Премия присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. " />
#
#         <meta name="author" content="Илья Ферапонтов" />
#         <meta name="copyright" content="" />
#
#         <!-- for Facebook -->
#         <meta property="og:title" content="Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей" />
#                 <meta property="og:image" content="https://nplus1.ru/images/2021/10/11/7117bddc1d6a6e180ef208ba72511f03.jpg" />
#         <meta property="og:url" content="https://nplus1.ru/news/2021/10/11/econobel2021" />
#         <meta property="og:description" content="Премия присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. " />
#         <!-- for Twitter -->
#         <meta name="twitter:card" content="summary_large_image">
#         <meta name="twitter:site" content="@nplusodin" />
#         <meta name="twitter:title" content="Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей" />
#         <meta name="twitter:description" content="Премия присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. " />
#         <meta name="twitter:image" content="https://nplus1.ru/images/2021/10/11/7117bddc1d6a6e180ef208ba72511f03.jpg" />
#
#         <meta name="yandex-verification" content="8c90b02c84ac3b72" />
#         <meta name="pmail-verification" content="b419949322895fc9106e24ed01be58ac">
#
#
#         <link rel='alternate' type='application/rss+xml' title='RSS' href='https://nplus1.ru/rss'>
#
#     <link rel="stylesheet" href="/css/font-awesome.min.css">
#     <link rel="stylesheet" href="/css/main.min.css?v=1643976238">
#     <link rel="stylesheet" href="/css/desktop.min.css?v=1452887696">
#     <link rel="stylesheet" href="/css/tablet.min.css?v=1499281342">
#     <link rel="stylesheet" href="/css/mobile.min.css?v=1635965090">
#
#             <script src="//ajax.googleapis.com/ajax/libs/jquery/1.11.2/jquery.min.js"></script>
#
#     <script src="//cdnjs.cloudflare.com/ajax/libs/modernizr/2.8.3/modernizr.min.js"></script>
#
#             <script type="text/javascript" src="/js/lib/adfox.asyn.code.ver3.js"> </script>
# 		<script type="text/javascript" src="/js/lib/adfox.asyn.code.scroll.js"> </script>
# 	    <script src="https://yastatic.net/pcode/adfox/loader.js" crossorigin="anonymous"></script>
#         <script async id="__lxGc__rtr" type="text/javascript" src="//s.clickiocdn.com/t/195458/360.js"></script>
#         <script async type="text/javascript" src="//s.luxupcdnc.com/t/common_402.js"></script>
#
# 		<!--  ad -->
# 		<script type="text/javascript">
# 		    var __colAdLoaded = false;
# 		    var __topAdLoaded = false;
#
# 		    var __id = "";
#
# 		    function detectAd(id){
# 		        var _ad = document.getElementById("AdFox_banner_"+id);
# 		    	    console.debug(_ad);
#
# 		        __id = id;
# 		        if(_ad != null && _ad.innerHTML == ""){
# 		            $(".col-ad").remove();
# 		        }
# 		        __colAdLoaded = true;
# 		    }
# 		    function detectAdTop(id){
# 		        __topAdLoaded = true;
# 		    }
# 		</script>
# 		<!-- /ad -->
#
#
#
#
#
# <script type="application/ld+json">{"@context":"http://schema.org","@type":"NewsArticle","mainEntityOfPage":{"@type":"WebPage","@id":"https://nplus1.ru/news/2021/10/11/econobel2021"},"headline":"Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей","description":"Премия присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. ","image":"https://nplus1.ru/images/2021/10/11/7117bddc1d6a6e180ef208ba72511f03.jpg","author":{"@type":"Person","name":"Илья Ферапонтов"},"publisher":{"@type":"Organization","name":"N + 1","logo":{"@type":"ImageObject","url":"https://nplus1.ru/i/logo-alt.png"}},"datePublished":"2021-10-11"}</script>
# </head>
# <body style="background-image:url(https://nplus1.ru/images/2021/10/11/9c6bcb5f7c01c6d88d49410e16ebc003.jpg)" class="_inner  ">
#
# <div class="shadow-overlay"></div>
# <link property='' rel='stylesheet' href='//s.luxupcdnc.com/cp/all/cookies_policy.css' />
# <script type='text/javascript'>_cookies_policy = {dark:0,bottom:1,text:'Этот сайт использует cookies для улучшения качества работы',link:'Подробнее',href:'https://nplus1.ru/cookies-policy',button:'Закрыть'};</script>
# <script async type='text/javascript' src='//s.luxupcdnc.com/cp/all/cookies_policy.js'></script>
#
#
#
#
#
#
# <div class="thx-rospechat">Функционирует при финансовой поддержке Федерального агентства по печати и массовым коммуникациям (Роспечать)</div>
#
#     <div id="viewport">
# 	<div id="shadow"></div>
#         <div class="ad ad-top">
#
#
#
#
#
#                         	    <!-- bh1 -->
#
#
# <!--AdFox START-->
# <!--yandex_nplus1adv-->
# <!--Площадка: N + 1 / * / *-->
# <!--Тип баннера: Растяжка_100%х250-->
# <!--Расположение: <верх страницы>-->
# <div id="adfox_162739969569252320"></div>
# <script>
#     window.yaContextCb.push(()=>{
#         Ya.adfoxCode.create({
#             ownerId: 386110,
#         containerId: 'adfox_162739969569252320',
#             params: {
#                 pp: 'g',
#             ps: 'fbio',
#             p2: 'hhkj'
#             }
#         })
#     })
# </script>
#
#
#
#
#         </div>
#         <header id="header-mobile">
#
#             <div class="container">
#                 <a href="#" class="action-menu pull-left"><i class="icon icon-navicon"></i></a>
#                 <a href="/" class="link-logo"><img src="/i/logo-mobile.png"/></a>
#                 <a href="#" class="action-search pull-right"><i class="icon icon-search"></i></a>
#                 <form action="/search" method="get" class="form-search">
#                     <div class="control">
#                         <input type="text" name="q" placeholder="Найти" value=""/>
#                     </div>
#                     <a href="#" class="action-search-close">×</a>
#                 </form>
#             </div>
#             <nav class="nav-rubrics">
#     <ul>
#                 <li>
#             <a href="/rubric/astronomy" class="">Астрономия</a>
#         </li>
#                 <li>
#             <a href="/rubric/physics" class="">Физика</a>
#         </li>
#                 <li>
#             <a href="/rubric/biology" class="">Биология</a>
#         </li>
#                 <li>
#             <a href="/rubric/robots-drones" class="">Роботы и дроны</a>
#         </li>
#
#                                     <li>
#                     <a href="/theme/bookshelf" class="">Книжная полка</a>
#                 </li>
#                             <li>
#                     <a href="/theme/Courses" class="">Курсы</a>
#                 </li>
#                             <li>
#                     <a href="/theme/coronavirus-history" class="">Коронавирусные хроники</a>
#                 </li>
#                             <li>
#                     <a href="/theme/offline" class="">N + Offline</a>
#                 </li>
#                             <li>
#                     <a href="/theme/icm22" class="">ICM2022</a>
#                 </li>
#
#             </ul>
# </nav>
#
#         </header>
#
#
#         <div id="layout" class="js-mediator-container">
#             <!-- header -->
#                         <header id="header" class="_middle">
#     <div class="row">
#
#         <div class="col col-logo">
#             <a href="/" class="link-logo"></a>
#         </div>
#         <div class="col col-nav-main">
#             <form action="/search" method="get" class="form-search">
#                 <div class="control">
#                     <input type="text" name="q" placeholder="Найти" value=""/>
#                 </div>
#                 <a href="#" class="action-search-close">×</a>
#             </form>
#
#             <nav class="nav-rubrics">
#     <ul>
#                 <li>
#             <a href="/rubric/astronomy" class="">Астрономия</a>
#         </li>
#                 <li>
#             <a href="/rubric/physics" class="">Физика</a>
#         </li>
#                 <li>
#             <a href="/rubric/biology" class="">Биология</a>
#         </li>
#                 <li>
#             <a href="/rubric/robots-drones" class="">Роботы и дроны</a>
#         </li>
#
#
#                 <li>
#             <a href="#" class="action-search"><i class="icon icon-search"></i></a>
#         </li>
#             </ul>
# </nav>            <nav class="nav-themes">
#     <ul>
#                 <li data-name="bookshelf">
#             <a href="/theme/bookshelf" class="">Книжная полка</a>
#         </li>
#                 <li data-name="Courses">
#             <a href="/theme/Courses" class="">Курсы</a>
#         </li>
#                 <li data-name="coronavirus-history">
#             <a href="/theme/coronavirus-history" class="">Коронавирусные хроники</a>
#         </li>
#                 <li data-name="offline">
#             <a href="/theme/offline" class="">N + Offline</a>
#         </li>
#                 <li data-name="icm22">
#             <a href="/theme/icm22" class="">ICM2022</a>
#         </li>
#             </ul>
# </nav>
#         </div>
#     </div>
#         <div class="container line-up">
#         <div class="line line-second">
#                                             <a href="https://nplus1.ru/blog/2022/02/08/the-bible-and-reality" class="action-line-toggle">
#                     <div class="heading"><span></span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2022/02/08/the-bible-and-reality" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Андрей Десницкий &laquo;Библия: Что было &quot;на самом деле&quot;?&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2022/02/04/a-demon-haunted-land" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Моника Блэк &laquo;Земля, одержимая демонами: Ведьмы, целители и призраки прошлого в послевоенной Германии&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2022/02/01/lower-than-zero" class="container-link">
#                     <div class="heading"><span>Коронавирусные хроники</span></div>
#                     <div class="link"><span>Вакцинация в убыток: что означает и откуда берется отрицательная эффективность &laquo;ЭпиВакКороны&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2022/01/31/the-zoologists-guide-to-the-galaxy" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Арик Кершенбаум &laquo;Путеводитель зоолога по Галактике&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2022/01/28/covid-symptoms" class="container-link">
#                     <div class="heading"><span>Коронавирусные хроники</span></div>
#                     <div class="link"><span>Их симптомы: почему мы болеем ковидом по-новому</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2022/01/25/galileo-and-the-science-deniers" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Марио Ливио &laquo;Галилей и отрицатели науки&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2022/01/20/this-is-your-brain-on-music" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Дэниел Левитин &laquo;На музыке: Наука о человеческой одержимости звуком&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2022/01/18/transitional-forms" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Андрей Журавлев &laquo;Похождения видов. Вампироноги, паукохвосты и другие переходные формы в эволюции животных&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2022/01/17/around-the-otherworld" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Олег Ивик &laquo;Вокруг того света. История и география загробного мира&raquo;</span></div>
#                 </a>
#                                                 		           	<a href="https://nplus1.ru/blog/2022/02/10/the-spike" class="container-link active">
#         	        	<div class="heading"><span>Книжная полка</span></div>
#             	    	<div class="link"><span>Марк Хамфрис &laquo;Скорость мысли. Грандиозное путешествие сквозь мозг за 2,1 секунды&raquo;</span></div>
# 		            </a>
#
#             <!-- here -->
#                     </div>
#
#     </div>
#     </header>                        <!-- /header -->
#             <!--  hero -->
#                             <!-- /hero -->
#             <!-- main section -->
#             <section id="main">
#
#
#     <div class="container _middle">
#         <div class="row" data-adaptive="1" data-tablet-class="row-wrap" data-mobile-class="row-wrap">
#             <div class="col col-3" data-adaptive="1" data-mobile-class="col-1">
#
#                 <article class="content" id="article" data-id="30917" data-visit="1" data-type="0">
#                                         <div class="meta">
#     <div class="tables">
#         <p class="table">
#                         <a data-rubric="economics" href="/rubric/economics">Экономика</a>
#                                                 <a data-theme="nobelprize" href="/theme/nobelprize">Нобелевская премия</a>
#                     </p>
#         <p class="table">
#             <a href="/news/2021/10/11">
#                 <time itemprop="datePublished" content="2021-10-11" data-unix="1633946665">
#                     <span>13:04</span>
#                     <span>11 Окт. 2021</span>
#                 </time>
#             </a>
#         </p>
#         <p class="table">
#             <a href="/difficult/1.1">
#                 <span>Сложность</span>
#                 <span class="difficult-value">1.1</span>
#             </a>
#         </p>
#     </div>
# </div>
# <script type="text/javascript">
#     var _dlData = {custom_rubric: []};
#         _dlData.custom_author = 'Илья Ферапонтов';
#         _dlData.custom_difficult = '1.1';
#         _dlData.custom_rubric.push('Экономика');
#                 _dlData.custom_theme = 'Нобелевская премия';
#
#     window.dataLayer = window.dataLayer || [];
#     window.dataLayer.push(_dlData);
# </script>
#                                         <div class="share-mobile">
#                         <nav class="nav-share">
#     <ul class="social-likes">
# 		<li class="facebook"></li>
# 		<li class="twitter"></li>
# 		<li class="vkontakte"></li>
# 		<li class="odnoklassniki"></li>
#     </ul>
# </nav>
#                     </div>
#
#                     <header class="hero hero-lite">
#                         <div>
#                             <h1>Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей</h1>
#                         </div>
#                     </header>
#                                         <div class="body js-mediator-article">
#                                                                                                                             <div class="article-image">
#                             <figure>
#                                 <img src="https://nplus1.ru/images/2021/10/11/9c6bcb5f7c01c6d88d49410e16ebc003.jpg"/>
#                                                                                             </figure>
#                         </div>
#
#                                                     <!-- -->
#                                                         <!-- -->
#
#                                                                                             <p>Премия Шведского национального банка по&nbsp;экономическим наукам памяти Альфреда Нобеля за&nbsp;2021 год присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. Прямая трансляция церемонии объявления лауреатов <a href="https://www.nobelprize.org/" target="_blank">шла</a>&nbsp;на&nbsp;официальном сайте Нобелевской премии.</p>
#
# <div class="incut incut-gallery " data-id="30917">
#     <div class="swiper-container">
#         <div class="swiper-wrapper">
#                         <div class="swiper-slide">
#                 <figure>
#                     <div class="img">
#                         <img src="https://nplus1.ru/images/2021/10/11/b7a9e42f1e5ee878f1d7c50e01bdbe84.jpg"/>
#                     </div>
#                     <figcaption>
#                     <p class="title">Слева направо: Дэвид Карт, Джошуа Энгрист и Гвидо Имбенс.</p>
#
#                                             	    <p class="credits">Niklas Elmehed © Nobel Prize Outreach</p>
#
#                     </figcaption>
#                 </figure>
#                 <div class="share-incut">
# <div class="title"><i class="fa fa-share"></i><span>Поделиться</span></div>
# <nav class="nav-share">
#     <ul class="social-likes" data-title="Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей">
# 		<li class="facebook" data-service='facebook' data-image='https://nplus1.ru/images/2021/10/11/b7a9e42f1e5ee878f1d7c50e01bdbe84.jpg', data-description='Niklas Elmehed &copy; Nobel Prize Outreach'></li>
# 		<li class="twitter" data-service='twitter' data-image='https://nplus1.ru/images/2021/10/11/b7a9e42f1e5ee878f1d7c50e01bdbe84.jpg', data-description='Niklas Elmehed &copy; Nobel Prize Outreach'></li>
# 		<li class="vkontakte" data-service='vkontakte' data-image='https://nplus1.ru/images/2021/10/11/b7a9e42f1e5ee878f1d7c50e01bdbe84.jpg', data-description='Niklas Elmehed &copy; Nobel Prize Outreach'></li>
# 		<li class="odnoklassniki" data-service='odnoklassniki' data-image='https://nplus1.ru/images/2021/10/11/b7a9e42f1e5ee878f1d7c50e01bdbe84.jpg', data-description='Niklas Elmehed &copy; Nobel Prize Outreach'></li>
#             </ul>
# </nav>
# </div>
#             </div>
#                     </div>
#         <div class="pagination">
#             <div class="swiper-button-prev"></div>
#             <div class="swiper-counter"></div>
#             <div class="swiper-button-next"></div>
#         </div>
#     </div>
# </div>Премия по&nbsp;экономике, в&nbsp;отличие от&nbsp;Нобелевских премий по&nbsp;физиологии и&nbsp;медицине, физике, химии и&nbsp;литературе, а&nbsp;также премии мира, была учреждена не&nbsp;самим Альфредом Нобелем, а&nbsp;Банком Швеции в&nbsp;1968&nbsp;году. Ее&nbsp;размер равен размеру остальных премий.<p>Лауреаты этого года награждены за их исследования причинно-следственных связей в области социальных наук. В частности, Дэвид Кард из университета Калифорнии в Беркли начиная с 1990-х годов исследовал, как именно на рынок труда влияют изменения минимальных зарплат, уровень иммиграции и образовательный уровень населения. Полученные им результаты, в частности, указывали, что повышение уровня минимальных зарплат не обязательно влечет за собой сокращение количества рабочих мест.</p><p>Два других лауреата - Джошуа Ангрист из Массачусетского технологического института и Гвидо Имбенс из Стэнфордского университета исследовали, как можно установить наличие причинно-следственных связей в естественных экспериментах, связанных с поисками отношения между уровнем образования и доходами.</p><p>Компания Clarivate, которая составляет списки потенциальных нобелевских лауреатов на&nbsp;основе наукометрических данных, в&nbsp;2021 году <a href="https://nplus1.ru/blog/2021/09/22/clarivate-prognosis-2021" target="_blank">предположила</a>, что в&nbsp;экономической номинации премию могут присудить Дэвиду Одречу (David Audretsch) и&nbsp;Дэвиду Тису (David Teece) за&nbsp;исследование инноваций.</p>
#
# <p>Кроме того, в&nbsp;списке этого года были Джоэл Мокир (Joel Mokyr), который исследует культурные истоки промышленной революции, а&nbsp;также Кармен Рейнхарт (Carmen Reinhart) и&nbsp;Кеннет Рогофф (Kenneth Rogoff)&nbsp;— авторы гипотезы «90-процентного порога»., согласно которой, когда внешний долг государства достигает 90&nbsp;процентов от&nbsp;ВВП, скорость роста ВВП падает вдвое.</p>
#
# <p>В&nbsp;2020 году премию по&nbsp;экономике присудили Полу Милгрому и&nbsp;Роберту Уилсону за&nbsp;развитие теории аукционов и&nbsp;изобретение новых форматов аукционов. Лауреаты исследовали, как работают аукционы, и&nbsp;разрабатывали новые форматы проведения аукционов для продажи товаров и&nbsp;услуг, которые трудно продавать с&nbsp;помощью традиционных методов. Читайте об&nbsp;их&nbsp;работах в&nbsp;нашем материале <a href="https://nplus1.ru/material/2020/10/13/nobel-econ-2020" target="_blank">«Тонкости молотка»</a>.</p>
#
# <p>В 2019 году премии памяти Нобеля по&nbsp;экономике были удостоены Абхиджит Банерджи, Эстер Дюфло и&nbsp;Майкл Кремер&nbsp;— «за&nbsp;экспериментальный подход к&nbsp;искоренению глобальной бедности». Подробнее о&nbsp;заслугах лауреатов можно прочесть в&nbsp;нашем материале&nbsp;<a href="https://nplus1.ru/material/2019/10/14/nobeleconomic" target="_blank" title="Link: https://nplus1.ru/material/2019/10/14/nobeleconomic">«Опыты на&nbsp;бедных»</a>. В&nbsp;2018 года награда была присуждена Уильяму Нордхаусу за&nbsp;«интеграцию изменения климата в&nbsp;долгосрочный макроэкономический анализ» и&nbsp;Полу Ромеру за&nbsp;«интеграцию технологических инноваций в&nbsp;долгосрочный макроэкономический анализ». Об&nbsp;их&nbsp;работах можно прочитать в&nbsp;материале <a href="https://nplus1.ru/material/2018/10/08/econobel-2018" target="_blank">«Почем знания для природы»</a>.</p>
#
# <p><i>Сергей Кузнецов</i></p>
#
#
#
#
#                                             </div>
#                 </article>
#
#
# 				    <!-- ba1 -->
# <!--AdFox START-->
# <!--nplus1_dir-->
# <!--Площадка: https://nplus1.ru/ / * / *-->
# <!--Тип баннера: CLICKIO html5-->
# <!--Расположение: мобильный-->
# <div id="adfox_155980540701252236"></div>
# <script>
#     window.Ya.adfoxCode.createAdaptive({
#         ownerId: 248569,
#         containerId: 'adfox_155980540701252236',
#         params: {
#             pp: 'ssg',
#             ps: 'cggm',
#             p2: 'fpum',
#             puid1: ''
#         }
#     }, ['phone'], {
#         tabletWidth: 1024,
#         phoneWidth: 767,
#         isAutoReloads: false
#     });
# </script>
#
#
# 		                <meter class="bottom"></meter>
#             </div>
#             <div class="col col-1 sidebar" data-adaptive="1" data-tablet-class="col-full">
#                                 <nav class="nav-share">
#     <ul class="social-likes">
# 		<li class="facebook"></li>
# 		<li class="twitter"></li>
# 		<li class="vkontakte"></li>
# 		<li class="odnoklassniki"></li>
#     </ul>
# </nav>
#
#                                 <div class="ad">
#                                                                 	                            	<!-- ba2 -->
# <!--AdFox START-->
# <!--nplus1_dir-->
# <!--Площадка: https://nplus1.ru/ / * / *-->
# <!--Тип баннера: CLICKIO html5-->
# <!--Расположение: <верх страницы>-->
# <div id="adfox_153934342663011746"></div>
# <script>
#     (function(w, n) {
#     w[n] = w[n] || [];
#     w[n].push({
#         ownerId: 248569,
#         containerId: 'adfox_153934342663011746',
#         params: {
#             pp: 'g',
#             ps: 'cggm',
#             p2: 'fpum',
#             puid1: ''
#         }
#     });})(window, 'adfoxAsyncParams');
# </script>
#
#
#                     	                                                                </div>
#
#
#                 <meter class="top"></meter>
#
#
#
#
#                     <div id="latest" data-adaptive="1" data-tablet-class="fixed" data-mobile-class="fixed">
#
#                         <h2 class="_tablet-hidden _mobile-hidden">Свежее</h2>
#                         <div class="latest-container">
#                         <article class="item item-news item-news-latest-first  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2022/02/14/wd-habitable-zone" data-id="32282" >
#         <div class="caption">
#                                                                     	                		<img src="https://nplus1.ru/images/2022/02/13/d719b42f701a7717b7b5c224c51bc8a4.jpg"/>
#
#
#
#                                     <div>
#                         <div class="date">
#                             <span class="name" title="2022-02-14">10:29</span>
#                         </div>
#                         <h3>Астрономы впервые отыскали кольцо из планетарных обломков в обитаемой зоне белого карлика</h3>
#                     </div>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                                                <article class="item item-news item-news-  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2022/02/14/lizard" data-id="32281" >
#         <div class="caption">
#
#
#                                 <div class="date">
#                     <span class="name" title="2022-02-14">09:24</span>
#                 </div>
#
#                                     <h3>Модель Изинга описала узор на спине глазчатой ящерицы</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                        <article class="item item-news item-news-  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2022/02/12/grotta-romanelli" data-id="32279" >
#         <div class="caption">
#
#
#                                 <div class="date">
#                     <span class="name" title="2022-02-12">12 февраля</span>
#                 </div>
#
#                                     <h3>Археологи нашли в пещере Романелли фалангу пальца ребенка эпохи верхнего палеолита</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                        <article class="item item-news item-news-  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2022/02/12/preactivation-hypotension" data-id="32280" >
#         <div class="caption">
#
#
#                                 <div class="date">
#                     <span class="name" title="2022-02-12">12 февраля</span>
#                 </div>
#
#                                     <h3>Движение коленом помогло женщинам снизить симптомы головокружения после вставания </h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                        <article class="item item-news item-news-  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2022/02/12/middle-paleolithic" data-id="32278" >
#         <div class="caption">
#
#
#                                 <div class="date">
#                     <span class="name" title="2022-02-12">12 февраля</span>
#                 </div>
#
#                                     <h3>На Алтае нашли пещеру с каменными орудиями денисовского облика</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                </div>
#
#
#
#
#
#
#                     </div>
#
#
#
#                 </div>
#
#                 <footer class="article-footer">
#                     <div class="row">
#                         <div class="col col-3" data-adaptive="1" data-mobile-class="col-1">
#                             <p>Нашли опечатку? Выделите фрагмент и нажмите Ctrl+Enter.</p>
#                         </div>
#                         <div class="col col-1 _mobile-hidden _tablet-hidden">
#                             <nav class="nav-share">
#     <ul class="social-likes">
# 		<li class="facebook"></li>
# 		<li class="twitter"></li>
# 		<li class="vkontakte"></li>
# 		<li class="odnoklassniki"></li>
#     </ul>
# </nav>
#                         </div>
#                     </div>
#                 </footer>
#
#                 <div class="ad ad-footer">
#                     			                                                                                        </div>
#
#
#             </div>
#
#
#             <div class="row row-wrap">
#                             </div>
#             <div class="row row-wrap">
#                 <div class="col col-full" data-adaptive="1"  data-mobile-class="col-1">
#
#                                     </div>
#             </div>
#             <div class="row" data-adaptive="1" data-tablet-class="row-wrap" data-mobile-class="row-wrap" data-type="also">
#                 <div class="col col-3" data-adaptive="1" data-mobile-class="col-1">
#
#                                         <section id="also">
#                                                 <h4 class="pull-left">Читайте также</h4>
#                         <div class="col col-also">
#                                                             <article class="item item-news item-news-ill  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2022/02/14/wd-habitable-zone" data-id="32282" >
#         <div class="caption">
#                             <div style="background-image:url(https://nplus1.ru/images/2022/02/13/d719b42f701a7717b7b5c224c51bc8a4.jpg)" class="ill"></div>
#
#
#
#                                     <h3>Астрономы впервые отыскали кольцо из планетарных обломков в обитаемой зоне белого карлика</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                            <article class="item item-news item-news-ill  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2022/02/14/lizard" data-id="32281" >
#         <div class="caption">
#                             <div style="background-image:url(https://nplus1.ru/images/2022/02/13/328be432c5d5fba29867bf0ed1490e8e.png)" class="ill"></div>
#
#
#
#                                     <h3>Модель Изинга описала узор на спине глазчатой ящерицы</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                            <article class="item item-news item-news-ill  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2022/02/12/grotta-romanelli" data-id="32279" >
#         <div class="caption">
#                             <div style="background-image:url(https://nplus1.ru/images/2022/02/12/d63e47988ca12703a55b0fafa0e0bfaf.jpg)" class="ill"></div>
#
#
#
#                                     <h3>Археологи нашли в пещере Романелли фалангу пальца ребенка эпохи верхнего палеолита</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                    </div>
#
#                     </section>
#                                     </div>
#                 <div class="col col-1" data-adaptive="1" data-tablet-class="col-full _indent-bottom">
#                     <section id="next">
#                         <div class="col col-1" data-adaptive="1" data-tablet-class="col-2">
#                                                         <article class="item item-article item-article-secondary  _exist-image" data-relevance="" data-image="https://nplus1.ru/images/2022/02/03/3e2bd15dc86be3d8e8053688d71ce45d.jpg" style=background-image:url(https://nplus1.ru/images/2022/02/03/34bd55e989c79caf4d53d011d99e550f.jpg)>
#
#     <a href="/material/2022/02/10/lanit-test" data-id="32140" >
#         <div class="caption">
#                                                                                     <h3>Колесо DevOpSansara</h3>
#                     <p class="subtitle">Преодолейте тяжелые испытания и заслужите достойное перерождение</p>
#                                     </div>
#     </a>
#         <nav class="nav-rubricator">
#         <ul>
#
#                         <li>
#                 <a class="link-rubric" href="/rubric/partners">Партнерский материал</a>
#             </li>
#                                 </ul>
#     </nav>
#     </article>                                                    </div>
#                     </section>
#                 </div>
#             </div>
#         </div>
#     <!--/div-->
#
#     <div id="_mistake">
#         <input type="hidden" name="_token" value="JqNF7xJkiSPixcEoKo2SLsvsX5tr48KAfOFkKO1o">
#         <input type="hidden" name="id_news" value="30917">
#         <input type="hidden" name="id_author" value="120">
#         <input type="hidden" name="id_editor" value="0">
#     </div>
#     <div id="_post">
#         <input type="hidden" name="_token" value="JqNF7xJkiSPixcEoKo2SLsvsX5tr48KAfOFkKO1o">
#         <input type="hidden" name="id_news" value="30917">
#     </div>
#             </section>
#             <!-- / main section -->
#
#
#             <div id="wrapper-footer">
#             <section id="difficult" class="_middle">
#     <!-- Slider main container -->
#     <div class="swiper-container">
#         <!-- Additional required wrapper -->
#         <div class="swiper-wrapper">
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">7.7</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2022/02/08/cyclotron-resonance-overtones">Медленные плазмоны сделали графен аномальным поглотителем</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">6.6</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2022/02/08/ultrafast-demagnetization">Избыток углового момента при сверхбыстром размагничивании ушел к фононам</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">6.2</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2022/02/11/POM-clusters">Кластерные полиоксометаллаты собрались в двумерные пористые структуры</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">5.8</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2022/02/10/sponge-gardens">Арктические губковые сады выросли на остатках исчезнувшей тысячи лет назад экосистемы</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">5.8</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2022/02/09/superionic-iron-alloys">Суперионные сплавы железа обвинили в сильном замедлении сейсмических волн в центре Земли</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">5.8</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2022/02/07/melting-sosulkas">Аномальность воды повлияла на вариативность подводных сосулек</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">5.7</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/material/2022/02/10/lanit-test">Колесо DevOpSansara</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">5.5</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2022/02/07/neptune-to-earth">Астрономы застали два мини-нептуна за превращением в суперземли</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">5.4</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2022/02/09/icecube-monopoles">IceCube не увидел магнитных монополей за восемь лет наблюдений</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">5.3</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2022/02/14/wd-habitable-zone">Астрономы впервые отыскали кольцо из планетарных обломков в обитаемой зоне белого карлика</a></h3>
#             </div>
#
#         </div>
#         <!-- If we need pagination -->
#         <div class="swiper-pagination"></div>
#         <div class="swiper-button-prev"></div>
#         <div class="swiper-button-next"></div>
#     </div>
#     <h6>Самое сложное</h6>
# </section>
#
#
#             <div class="ad ad-col border">
#                     	    </div>
#
#             <!-- footer -->
#             <footer id="footer">
#     <div class="row" data-adaptive="1" data-middle-class="row-wrap" data-tablet-class="row-wrap" data-mobile-class="row-wrap">
#         <div class="col col-logo">
#             <a href="/" class="link-logo"><img src="/i/logo-alt.png"/></a>
#         </div>
#         <div class="col col-footer-desc">
#             <nav class="nav-pages">
#                 <ul>
#                     <li>
#                         <a href="/about">О нас</a>
#                     </li>
#                     <li>
#                         <a href="https://nplus.pro" target="_blank">N + Production</a>
#                     </li>
#                     <li>
#                         <a href="/adv">Рекламодателям</a>
#                     </li>
#                     <li>
#                         <a href="/rules">Наши материалы</a>
#                     </li>
#                     <li>
#                         <a href="/vacancy">Вакансии</a>
#                     </li>
#                     <li>
#                         <a href="/difficult">Сложность</a>
#                     </li>
#                 </ul>
#             </nav>
#             <div class="desc">
#                 <p>&copy; 2022 <i>N&nbsp;+&nbsp;1</i> Интернет-издание &nbsp; Свидетельство о регистрации СМИ Эл № ФС77-67614</p>
#
#                     <p>Использование всех текстовых материалов без изменений в некоммерческих целях разрешается со ссылкой на <i>N&nbsp;+&nbsp;1</i>.
#                         Все аудиовизуальные произведения являются собственностью своих авторов и правообладателей и используются
#                         только в образовательных и информационных целях. Если вы являетесь собственником того или иного произведения
#                         и не согласны с его размещением на нашем сайте, пожалуйста, напишите на kirill@nplus1.ru</p>
#                     <p>Материалы, опубликованные в разделе «Блоги», отражают позиции их авторов, которые могут не совпадать с мнением редакции.</p>
#                     <p>Сайт может содержать контент, не предназначенный для лиц младше 18 лет.</p>
#                     <p>Связь с редакцией: <a href="mailto:info@nplus1.ru">info@nplus1.ru</a></p>
#                     <p>
#                         <a href="https://nplus1.ru/personal-data-policy" class="pd">Политика обработки персональных данных пользователей сайта</a>
#                     </p>
#                     <p>
#                         <script async type="text/javascript" src="//s.luxupcdnc.com/t/consent_195458.js"></script>
#                         <a href="#" onclick="if(window.__lxG__consent__ !== undefined) {window.__lxG__consent__.showConsent()} else {alert('This function works only for users from the European Economic Area (EEA).')}; return false">Change privacy settings</a>
#                     </p>
#
#                 <p>
#                                     </p>
#             </div>
#         </div>
#         <div class="col col-1 pull-right">
#             <nav class="nav-social">
#                 <ul>
#                     <li>
#                         <a href="https://t.me/nplusone"><i class="fa fa-telegram"></i></a>
#                     </li>
#                     <li>
#                         <a href="http://vk.com/nplusone"><i class="fa fa-vk"></i></a>
#                     </li>
#                     <li>
#                         <a href="https://www.facebook.com/nplusone"><i class="fa fa-facebook"></i></a>
#                     </li>
#                     <li>
#                         <a href="https://twitter.com/nplusodin"><i class="fa fa-twitter"></i></a>
#                     </li>
#                     <li>
#                         <a href="https://ok.ru/nplus1"><i class="fa fa-odnoklassniki"></i></a>
#                     </li>
#                     <li>
#                         <a href="https://soundcloud.com/nplus_1"><i class="fa fa-soundcloud"></i></a>
#                     </li>
#                     <li>
#                         <a href="/rss"><i class="fa fa-rss"></i></a>
#                     </li>
#                 </ul>
#             </nav>
#             <div class="partners">
#
#
#                 <!-- Rating@Mail.ru counter -->
# <script type="text/javascript">
# var _tmr = window._tmr || (window._tmr = []);
# _tmr.push({id: "3084572", type: "pageView", start: (new Date()).getTime()});
# (function (d, w, id) {
#   if (d.getElementById(id)) return;
#   var ts = d.createElement("script"); ts.type = "text/javascript"; ts.async = true; ts.id = id;
#   ts.src = "https://top-fwz1.mail.ru/js/code.js";
#   var f = function () {var s = d.getElementsByTagName("script")[0]; s.parentNode.insertBefore(ts, s);};
#   if (w.opera == "[object Opera]") { d.addEventListener("DOMContentLoaded", f, false); } else { f(); }
# })(document, window, "topmailru-code");
# </script><noscript><div>
# <img src="https://top-fwz1.mail.ru/counter?id=3084572;js=na" style="border:0;position:absolute;left:-9999px;" alt="Top.Mail.Ru" />
# </div></noscript>
# <!-- //Rating@Mail.ru counter -->
#
#
#
#             </div>
#         </div>
#     </div>
# </footer>            <!-- / footer -->
#             </div>
#         </div>
#
#     </div>
#
#
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-MNJC58');</script>
# <!-- End Google Tag Manager -->
#
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-MNJC58"
# height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
#
#
#
#     <noscript><div><img src="//mc.yandex.ru/watch/29654565" style="position:absolute; left:-9999px;" alt="" /></div></noscript>
#
#
# 	</div>
#
#
#
# <script src="/js/lib/js.cookie.js"></script>
# <script src="/js/lib/jquery.swap.js"></script>
# <script src="/js/lib/swiper.jquery.min.js"></script>
# <script src="/js/lib/svg.js"></script>
# <script src="/js/lib/jquery.mobile-events.min.js"></script>
# <script src="/js/lib/social-likes.min.js"></script>
# <script src="/js/lib/jquery.sticky.js"></script>
#
#
# <script src="/js/lib/ts.js"></script>
# <script src="/js/lib/js.cookie.js"></script>
#
#
# <script async src="https://cdn.onthe.io/io.js/QCyUUwp6IVuR"></script>
# <script>
# window._io_config = window._io_config || {};
# window._io_config["0.2.0"] = window._io_config["0.2.0"] || [];
# window._io_config["0.2.0"].push({
#     page_url: document.location.toString(),
#     page_url_canonical: document.querySelector('link[rel="canonical"]').href,
#     page_title: document.querySelector('title').innerHTML,
#     page_type: "article",
#     page_language: "ru",
#     article_authors: [document.querySelector('meta[name="author"]').content || ''],
#     article_publication_date: (new Date(document.querySelector('meta[itemprop="datePublished"]').content).toUTCString()).toString()
# });
# </script>
#
# <!--   project scripts -->
# <script src="/js/main.min.js?v=1643976149"></script>
# <!-- / project scripts -->
#
#
#
#
# <!-- Quantcast Tag -->
# <script type="text/javascript">
# var _qevents = _qevents || [];
#
# (function() {
# var elem = document.createElement('script');
# elem.src = (document.location.protocol == "https:" ? "https://secure" : "http://edge") + ".quantserve.com/quant.js";
# elem.async = true;
# elem.type = "text/javascript";
# var scpt = document.getElementsByTagName('script')[0];
# scpt.parentNode.insertBefore(elem, scpt);
# })();
#
# _qevents.push({
# qacct:"p-s3ftDEFzEW5x7"
# });
# </script>
#
# <noscript>
# <div style="display:none;">
# <img src="//pixel.quantserve.com/pixel/p-s3ftDEFzEW5x7.gif" border="0" height="1" width="1" alt="Quantcast"/>
# </div>
# </noscript>
# <!-- End Quantcast tag -->
# </body>
# </html>

# %% [markdown]
# 5. Библиотека BeautifulSoup

# %%
from bs4 import BeautifulSoup

# %%
url = 'https://nplus1.ru/news/2021/10/11/econobel2021' # Определяем адрес страницы
response = requests.get(url) # Выполняем GET-запрос, содержимое ответа присваивается переменной response
page = BeautifulSoup(response.text, 'html.parser') # Создаём объект BeautifulSoup, указывая html-парсер
print(page.title) # Получаем тег title, отображающийся на вкладке браузера
print(page.title.text) # Выводим текст из полученного тега, который содержится в атрибуте text
# Out:
# Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей

# %% [markdown]
# ИЗВЛЕКАЕМ ЗАГОЛОВОК И ВРЕМЯ НАПИСАНИЯ СТАТЬИ

# %%
print(page.find('h1').text) # Применяем метод find() к объекту и выводим результат на экран
# Out:
# Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей

# %%
print(page.find('time').text) # Выводим на экран содержимое атрибута text тега time
# Out:
# 13:04
# 11 Окт. 2021

# %% [markdown]
# Задание 5.4
#
# Напишите функцию wiki_header, которая по адресу страницы возвращает заголовок для статей на Wikipedia.

# %%
import requests
from bs4 import BeautifulSoup

def wiki_header(url):
    response = requests.get(url)
    page = BeautifulSoup(response.text, 'html.parser')
    return (page.find('h1').text)

wiki_header('https://en.wikipedia.org/wiki/Operating_system')
'Operating system'
# Out:
# 'Operating system'

# %% [markdown]
# НЕУНИКАЛЬНЫЕ ТЕГИ: ИЗВЛЕКАЕМ ТЕКСТ СТАТЬИ

# %%
print(page.find('div').text) # Выводим содержимое атрибута text тега div

# %%
print(page.find('div', class_='body').text) # Выводим содержимое атрибута text тега div класса body js-mediator-article

# %% [markdown]
# СБОР НЕСКОЛЬКИХ ЭЛЕМЕНТОВ: СОБИРАЕМ ВСЕ ССЫЛКИ НА СТРАНИЦЕ

# %%
url = 'https://en.wikipedia.org/wiki/List_of_programming_languages' # Задаём адрес ресурса
response = requests.get(url) # Делаем GET-запрос к ресурсу
page = BeautifulSoup(response.text, 'html.parser') # Создаём объект BeautifulSoup
print(page.find('a')) # Ищем ссылку по тегу <a> и выводим её на экран
# Out:
# <a id="top"></a>

# %%
links = page.find_all('a') # Ищем все ссылки на странице и сохраняем в переменной links в виде списка
print(len(links)) # Выводим количество найденных ссылок
# Out:
# 929

# %%
print([link.text for link in links[500:510]]) # Выводим ссылки с 500 по 509 включительно
# Out:
# ['ORCA/Modula-2', 'Oriel', 'Orwell', 'Oxygene', 'Oz', 'edit', 'P', 'P4', 'P′′', 'ParaSail']

# %%
print([link.text for link in links[0:10]]) # Выводим ссылки с 1 по 9 включительно
# Out:
# ['', 'Jump to navigation', 'Jump to search', 'Programming languagelists', 'Alphabetical', 'Categorical', 'Chronological', 'Generational', 'v', 't']

# %% [markdown]
# ПЕРВЫЕ ЗАПРОСЫ К API

# %% [markdown]
# ЗАПРОС К API ИЗ КОДА

# %%
import requests # Импортируем модуль requests
token = 'd07d37d0d07d37d0d07d37d04fd0067b86dd07dd07d37d0b27667e9d71ac62943869309' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/users.get' # Указываем адрес страницы к которой делаем запрос
params = {'user_id': 1, 'v': 5.95, 'fields': 'sex,bdate', 'access_token': token, 'lang': 'ru'} # Перечисляем параметры нашего запроса в словаре params
response = requests.get(url, params=params) # Отправляем запрос
print(response.text) # Выводим текст ответа на экран
# Out:
# {"response":[{"id":1,"first_name":"Павел","last_name":"Дуров","can_access_closed":true,"is_closed":false,"sex":2,"bdate":"10.10.1984"}]}

# %%
from pprint import pprint # Импортируем функцию pprint()
pprint(response.json()) # Выводим содержимое словаря, содержащего ответ, на экран
# Out:
# {'response': [{'bdate': '10.10.1984',
#                'can_access_closed': True,
#                'first_name': 'Павел',
#                'id': 1,
#                'is_closed': False,
#                'last_name': 'Дуров',
#                'sex': 2}]}

# %%
user = response.json()['response'][0] # Извлекаем из словаря по ключу response информацию о первом пользователе
print(user['bdate']) # Выводим дату рождения первого пользователя на экран
# Out:
# 10.10.1984

# %%
print(user['first_name'])
# Out:
# Павел

# %%
ids = ",".join(map(str, range(1, 4))) # Формируем строку, содержащую информацию о поле id первых трёх пользователей
params = {'user_ids': ids, 'v': 5.95, 'fields': 'bday', 'access_token': token, 'lang': 'ru'} # Формируем строку параметров
pprint(requests.get(url, params=params).json()) # Посылаем запрос, полученный ответ в формате JSON-строки преобразуем в словарь и выводим на экран его содержимое, используя функцию pprint()
# Out:
# {'response': [{'can_access_closed': True,
#                'first_name': 'Павел',
#                'id': 1,
#                'is_closed': False,
#                'last_name': 'Дуров'},
#               {'can_access_closed': False,
#                'first_name': 'Александра',
#                'id': 2,
#                'is_closed': True,
#                'last_name': 'Владимирова'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 3,
#                'last_name': ''}]}

# %% [markdown]
# Задание 6.2
#
# Используя API, определите долю женщин (sex=1) среди пользователей с id от 1 до 500. Иногда будут попадаться пользователи, у которых пол не указан (sex=0), — таких пользователей не нужно учитывать в общем числе.
#
# В ответе укажите число, округлив до двух знаков после точки-разделителя, например, 0.55.

# %%
ids = ",".join(map(str, range(1, 501)))
params = {'user_ids': ids, 'v': 5.95, 'fields': 'sex', 'access_token': token, 'lang': 'ru'}
response = requests.get(url, params=params).json()['response']
#pprint(response)
full_count = 0
women_count = 0
for elem in response:
    if elem['sex'] !=0:
        full_count += 1
        if elem['sex'] == 1:
            women_count += 1
print(round(women_count/full_count, 2))
# Out:
# 0.48

# %% [markdown]
# СБОР ИНФОРМАЦИИ ИЗ ГРУПП

# %%
url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес обращения
params = {'group_id': 'vk', 'v': 5.95, 'access_token': token} # Формируем строку параметров
response = requests.get(url, params = params) # Посылаем запрос
data = response.json() # Ответ сохраняем в переменной data в формате словаря
print(data) # Выводим содержимое переменной data на экран (отображён фрагмент)

# %%
print(len(data['response']['items'])) # Выводим на экран количество элементов словаря
# Out:
# 1000

# %%
users_for_checking = data['response']['items'][:20] # Загружаем в переменную информацию об id первых 20 пользователей в виде списка
print(users_for_checking) # Выводим перечень id первых 20 пользователей
# Out:
# [6, 19, 47, 54, 79, 177, 198, 212, 219, 239, 243, 345, 407, 467, 485, 510, 550, 619, 640, 690]

# %%
url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес обращения
count = 5 
offset = 0 
user_ids = [] 
max_count = 20 
while offset < max_count: 
    # Будем выгружать по count=5 пользователей, 
    # начиная с того места, где закончили на предыдущей итерации (offset) 
    print('Выгружаю {} пользователей с offset = {}'.format(count, offset))   
    params = {'group_id': 'vk', 'v': 5.95, 'count': count, 'offset': offset, 'access_token': token} 
    response = requests.get(url, params = params) 
    data = response.json() 
    user_ids += data['response']['items'] 
    # Увеличиваем смещение на количество строк, которое мы уже выгрузили 
    offset += count 
print(user_ids)
# Out:
# Выгружаю 5 пользователей с offset = 0
# Выгружаю 5 пользователей с offset = 5
# Выгружаю 5 пользователей с offset = 10
# Выгружаю 5 пользователей с offset = 15
# [6, 19, 47, 54, 79, 177, 198, 212, 219, 239, 243, 345, 407, 467, 485, 510, 550, 619, 640, 690]

# %%
print(user_ids == users_for_checking)
# Out:
# True

# %%
url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес обращения
count = 1000 
offset = 0 
user_ids = [] 
max_count = data['response']['count'] 
while offset < max_count: 
    # Будем выгружать по count=5 пользователей, 
    # начиная с того места, где закончили на предыдущей итерации (offset) 
    print('Выгружаю {} пользователей с offset = {}'.format(count, offset))   
    params = {'group_id': 'vk', 'v': 5.95, 'count': count, 'offset': offset, 'access_token': token} 
    response = requests.get(url, params = params) 
    data = response.json() 
    user_ids += data['response']['items'] 
    # Увеличиваем смещение на количество строк, которое мы уже выгрузили 
    offset += count 
print(user_ids)

# %% [markdown]
# ОГРАНИЧЕНИЕ ПО ЧАСТОТЕ ЗАПРОСОВ

# %%
import requests # Импортируем модуль requests
import time # Импортируем модуль time
token = 'd07d37d0d07d37d0d07d37d04fd0067b86dd07dd07d37d0b27667e9d71ac62943869309' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес страницы, к которой делаем запрос
count = 1000 
offset = 0  
user_ids = []  
while offset < 5000: 
    params = {'group_id': 'vk', 'v': 5.95, 'count': count, 'offset': offset, 'access_token': token} 
    response = requests.get(url, params = params) 
    data = response.json() 
    user_ids += data['response']['items'] 
    offset += count 
    print('Ожидаю 0.5 секунды...') 
    time.sleep(0.5) 
print('Цикл завершен, offset =',offset)
# Out:
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Цикл завершен, offset = 5000

# %% [markdown]
# ЛАЙКИ, РЕПОСТЫ И КОММЕНТАРИИ

# %%
import requests # Импортируем модуль requests
from pprint import pprint # Импортируем функцию pprint()
token = 'd07d37d0d07d37d0d07d37d04fd0067b86dd07dd07d37d0b27667e9d71ac62943869309' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/wall.get' # Указываем адрес страницы, к которой делаем запрос
params = {'domain': 'vk', 'filter': 'owner', 'count': 1000, 'offset': 0, 'access_token': token, 'v': 5.95} 
response = requests.get(url, params = params) 
pprint(response.json())
# Out:
# {'response': {'count': 467,
#               'items': [{'attachments': [{'photo': {'access_key': '3c18beec62ab6b65d8',
#                                                     'album_id': -7,
#                                                     'date': 1644840428,
#                                                     'id': 457328227,
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1275041,
#                                                     'sizes': [{'height': 55,
#                                                                'type': 's',
#                                                                'url': 'https://sun1-24.userapi.com/impg/PpwsjqPy_lmiyZYjP6PmMYBVgTa9KbYIuFE_Jg/MKHiXZmygK4.jpg?size=75x55&quality=95&sign=7dbab22b23b223b6fba3f4c55d83593a&c_uniq_tag=gIFTj5PP7885O463Y5OUc-RDjxXB40VptvJyc4UH1b0&type=album',
#                                                                'width': 75},
#                                                               {'height': 96,
#                                                                'type': 'm',
#                                                                'url': 'https://sun1-24.userapi.com/impg/PpwsjqPy_lmiyZYjP6PmMYBVgTa9KbYIuFE_Jg/MKHiXZmygK4.jpg?size=130x96&quality=95&sign=a003f57193eed24abecfd3269fce6ae7&c_uniq_tag=8iJDjHVOvLxrBHyp-RfUXvJeFIBZqZa1D5LPJ3_pRUc&type=album',
#                                                                'width': 130},
#                                                               {'height': 444,
#                                                                'type': 'x',
#                                                                'url': 'https://sun1-24.userapi.com/impg/PpwsjqPy_lmiyZYjP6PmMYBVgTa9KbYIuFE_Jg/MKHiXZmygK4.jpg?size=604x444&quality=95&sign=09c2b57b9b669df0c863f97d354c4f97&c_uniq_tag=0XN5IHAmSQH4WfTdPv_szCOOMJjOV30HAT3ZRvPOZIs&type=album',
#                                                                'width': 604},
#                                                               {'height': 593,
#                                                                'type': 'y',
#                                                                'url': 'https://sun1-24.userapi.com/impg/PpwsjqPy_lmiyZYjP6PmMYBVgTa9KbYIuFE_Jg/MKHiXZmygK4.jpg?size=807x593&quality=95&sign=fb9e08a380b4db34a188b30484ded3a1&c_uniq_tag=eePZchS-_wamLUJl3KU0VB5w5BhpKUO2K9l89dAXM2o&type=album',
#                                                                'width': 807},
#                                                               {'height': 941,
#                                                                'type': 'z',
#                                                                'url': 'https://sun1-24.userapi.com/impg/PpwsjqPy_lmiyZYjP6PmMYBVgTa9KbYIuFE_Jg/MKHiXZmygK4.jpg?size=1280x941&quality=95&sign=4e99e4184f3dcdf100b1e15ba27b51b4&c_uniq_tag=kx5qoVCGG_CTmjEho2X07REe9S2RL3V72SG7SEqUHoY&type=album',
#                                                                'width': 1280},
#                                                               {'height': 1470,
#                                                                'type': 'w',
#                                                                'url': 'https://sun1-24.userapi.com/impg/PpwsjqPy_lmiyZYjP6PmMYBVgTa9KbYIuFE_Jg/MKHiXZmygK4.jpg?size=2000x1470&quality=95&sign=8651d44462629bb95422998257ac4ee4&c_uniq_tag=tSp5HUVeuLfdpAydS1JFCGKWwu1cRIE40e40ZxtWBfI&type=album',
#                                                                'width': 2000},
#                                                               {'height': 96,
#                                                                'type': 'o',
#                                                                'url': 'https://sun1-24.userapi.com/impg/PpwsjqPy_lmiyZYjP6PmMYBVgTa9KbYIuFE_Jg/MKHiXZmygK4.jpg?size=130x96&quality=95&sign=a003f57193eed24abecfd3269fce6ae7&c_uniq_tag=8iJDjHVOvLxrBHyp-RfUXvJeFIBZqZa1D5LPJ3_pRUc&type=album',
#                                                                'width': 130},
#                                                               {'height': 147,
#                                                                'type': 'p',
#                                                                'url': 'https://sun1-24.userapi.com/impg/PpwsjqPy_lmiyZYjP6PmMYBVgTa9KbYIuFE_Jg/MKHiXZmygK4.jpg?size=200x147&quality=95&sign=75800d0f21be3e7106633acecf84f033&c_uniq_tag=9798UqagTbwkqIMoOJ8O_kBoYeP_KEu-ijTPbtAVPA4&type=album',
#                                                                'width': 200},
#                                                               {'height': 235,
#                                                                'type': 'q',
#                                                                'url': 'https://sun1-24.userapi.com/impg/PpwsjqPy_lmiyZYjP6PmMYBVgTa9KbYIuFE_Jg/MKHiXZmygK4.jpg?size=320x235&quality=95&sign=b0383bc288c1137b73117a704e1e6dbe&c_uniq_tag=FF44xOJfuTxCfPIUVbFuThRVkbzUBvb07t-FHWEymoM&type=album',
#                                                                'width': 320},
#                                                               {'height': 375,
#                                                                'type': 'r',
#                                                                'url': 'https://sun1-24.userapi.com/impg/PpwsjqPy_lmiyZYjP6PmMYBVgTa9KbYIuFE_Jg/MKHiXZmygK4.jpg?size=510x375&quality=95&sign=6613b1ca6f4ccb4d8067c72fc4510601&c_uniq_tag=yAIn8zkYbopeXxd8lLtaTFz45Q3bLIAkmZszF72s8DU&type=album',
#                                                                'width': 510}],
#                                                     'text': '',
#                                                     'user_id': 100},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 101,
#                                       'groups_can_post': True},
#                          'date': 1644840943,
#                          'from_id': -22822305,
#                          'hash': 'smdsXYzsODJgyDArxw',
#                          'id': 1275041,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 332,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 106, 'user_reposted': 0},
#                          'text': 'День святого Валентина — повод показать свои '
#                                  'чувства. Мы любим вас, поэтому подготовили '
#                                  'праздничные сюрпризы. Приоткрываем шкатулку '
#                                  '✨ \n'
#                                  '\n'
#                                  '📌 Отправляйте послания любимым и друзьям: '
#                                  'кидайте их в виртуальную '
#                                  '[https://vk.com/app6851096|«Коробку для '
#                                  'валентинок»]. Признания могут быть '
#                                  'анонимными — адресат увидит ваше имя, только '
#                                  'если тоже напишет вам. А ещё вы можете '
#                                  'отправить валентинку в 2023-й — уже не '
#                                  'скрывая чувств!\n'
#                                  '\n'
#                                  '📌 Ищете пару? Заглядывайте в '
#                                  '[https://vk.com/dating|VK Знакомства]. Всего '
#                                  'на один день некоторые премиум-функции стали '
#                                  'бесплатными. Ставьте суперлайки, '
#                                  'возвращайтесь к предыдущим профилям и '
#                                  'смотрите анкеты тех, кто проявил к вам '
#                                  'интерес. \n'
#                                  '\n'
#                                  '📌 А если хотите окунуться в романтику, '
#                                  'почитайте истории влюблённых из '
#                                  '[https://vk.com/youla_ru?w=wall-137839839_210399|Екатеринбурга] '
#                                  'и '
#                                  '[https://vk.com/vkclassifieds?w=wall-200241296_32397|Новосибирска]. '
#                                  'Они познакомились, когда покупали и '
#                                  'продавали товары в сервисах VK. Отношения '
#                                  'могут начаться неожиданно. Вот она, магия '
#                                  'любви ❤ \n'
#                                  '\n'
#                                  'И это далеко не все сюрпризы. Обнимайтесь в '
#                                  '[https://vk.com/calls|VK Звонках], украшайте '
#                                  'чаты, слушайте праздничные плейлисты в '
#                                  '[https://vk.com/music|VK Музыке]. А если вся '
#                                  'эта атмосфера вам не по душе, разбивайте '
#                                  'сердца в игре '
#                                  '[https://vk.com/antivalentine|«Краш-тест»]. \n'
#                                  '\n'
#                                  '🥰 Подробнее обо всех активностях читайте в '
#                                  'нашей новости: '
#                                  'vk.com/press/valentines-day-2022',
#                          'views': {'count': 108157}},
#                         {'attachments': [{'link': {'caption': 'vc.ru',
#                                                    'description': 'И что ждёт '
#                                                                   'сервис в '
#                                                                   '2022',
#                                                    'photo': {'album_id': -26,
#                                                              'date': 1644258069,
#                                                              'id': 457361589,
#                                                              'owner_id': 2000032858,
#                                                              'sizes': [{'height': 89,
#                                                                         'type': 'a',
#                                                                         'url': 'https://sun9-78.userapi.com/sun9-51/waEp3rn_2szSCKrOYIf-5LlNKL1JbaQ7HUbfBw/eHJ3-CbSUyw.jpg',
#                                                                         'width': 200},
#                                                                        {'height': 178,
#                                                                         'type': 'b',
#                                                                         'url': 'https://sun9-78.userapi.com/sun9-56/H02GSyyJO2hY1sWC3rSmXP7pIcQStu5ClcFrvA/wMjupmBTO9M.jpg',
#                                                                         'width': 400},
#                                                                        {'height': 200,
#                                                                         'type': 'c',
#                                                                         'url': 'https://sun9-78.userapi.com/sun9-7/oKg_6uQ9yBuT_wA4GCKkH5EKoDELlaj830DikQ/0fSsdjIelCU.jpg',
#                                                                         'width': 200},
#                                                                        {'height': 100,
#                                                                         'type': 'd',
#                                                                         'url': 'https://sun9-78.userapi.com/sun9-21/1xwHAFPRC3fNnAJnJtRV6swwRAehpPoZti5QqA/YiccL9hx1_M.jpg',
#                                                                         'width': 100},
#                                                                        {'height': 50,
#                                                                         'type': 'e',
#                                                                         'url': 'https://sun1-88.userapi.com/ss3Rgd8jsdLgQb1x3sEZ1BamO0_iAj4O1doojw/Ck6rXA2pQjE.jpg',
#                                                                         'width': 50},
#                                                                        {'height': 478,
#                                                                         'type': 'k',
#                                                                         'url': 'https://sun9-78.userapi.com/sun9-81/impg/O97nBus7kcrUdYbURgmdqn9iJa0Onlcoud00KA/RC9I6LAvWDg.jpg?size=1074x478&quality=96&sign=98dc443eaeece1970789f5a08b73e7f4&c_uniq_tag=rMl8NnyqXu3QeFKIZ3E-lqEuwZEDUoxHLeOnH0kU5lA&type=share',
#                                                                         'width': 1074},
#                                                                        {'height': 240,
#                                                                         'type': 'l',
#                                                                         'url': 'https://sun9-78.userapi.com/sun9-81/impg/O97nBus7kcrUdYbURgmdqn9iJa0Onlcoud00KA/RC9I6LAvWDg.jpg?size=537x239&quality=96&sign=4bc8bfb78d92004868e2692ff616315a&c_uniq_tag=mrxhPEOwEPcFOTCaZet9WPYjStfoKC-w1t9WkwuBX00&type=share',
#                                                                         'width': 537},
#                                                                        {'height': 855,
#                                                                         'type': 'o',
#                                                                         'url': 'https://sun9-78.userapi.com/sun9-88/S2lPCeLYJuhng4u5EeRK3MdO71_HFAWiYh1A2A/t6y155Y8POM.jpg',
#                                                                         'width': 1920}],
#                                                              'text': '',
#                                                              'user_id': 100},
#                                                    'title': 'Семь видов '
#                                                             'разрешения, '
#                                                             'автоматические '
#                                                             'субтитры и '
#                                                             'монетизация: как '
#                                                             'поменялось VK '
#                                                             'Видео в 2021 году',
#                                                    'url': 'https://vc.ru/vk/355139-sem-vidov-razresheniya-avtomaticheskie-subtitry-i-monetizaciya-kak-pomenyalos-vk-video-v-2021-godu'},
#                                           'type': 'link'}],
#                          'comments': {'can_post': 1,
#                                       'count': 561,
#                                       'groups_can_post': True},
#                          'date': 1644258069,
#                          'edited': 1644258102,
#                          'from_id': -22822305,
#                          'hash': 'X24VzjEuHQWlzcGNrw',
#                          'id': 1273877,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 2846,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 855, 'user_reposted': 0},
#                          'text': 'Нейросети на страже высокого качества, умные '
#                                  'рекомендации и автосубтитры — собрали все '
#                                  'главные обновления платформы VK Видео и '
#                                  'поделились планами на будущее в нашем блоге.',
#                          'views': {'count': 1543263}},
#                         {'attachments': [{'photo': {'access_key': '4ec86e95e13ba1705d',
#                                                     'album_id': -7,
#                                                     'date': 1642084583,
#                                                     'id': 457327501,
#                                                     'owner_id': -22822305,
#                                                     'sizes': [{'height': 91,
#                                                                'type': 'm',
#                                                                'url': 'https://sun1-57.userapi.com/impg/nhz2XSJLeRAh08aGlc73auLtJmamXAh8bhOo1g/OxiKB_m81O4.jpg?size=130x91&quality=96&sign=37d98f7c418621ad3fc8763c890e093d&c_uniq_tag=Qfp6tgLBdpsj8SQI4MSyRu2eAJSemki7bERv4wl8sZg&type=album',
#                                                                'width': 130},
#                                                               {'height': 91,
#                                                                'type': 'o',
#                                                                'url': 'https://sun1-57.userapi.com/impg/nhz2XSJLeRAh08aGlc73auLtJmamXAh8bhOo1g/OxiKB_m81O4.jpg?size=130x91&quality=96&sign=37d98f7c418621ad3fc8763c890e093d&c_uniq_tag=Qfp6tgLBdpsj8SQI4MSyRu2eAJSemki7bERv4wl8sZg&type=album',
#                                                                'width': 130},
#                                                               {'height': 140,
#                                                                'type': 'p',
#                                                                'url': 'https://sun1-57.userapi.com/impg/nhz2XSJLeRAh08aGlc73auLtJmamXAh8bhOo1g/OxiKB_m81O4.jpg?size=200x140&quality=96&sign=1b97182bb4273c6736be16dbf16dfb50&c_uniq_tag=xXNbYCl2w2XDYA5h53GHVkxoQ05ot7musCuZMwKyTBY&type=album',
#                                                                'width': 200},
#                                                               {'height': 224,
#                                                                'type': 'q',
#                                                                'url': 'https://sun1-57.userapi.com/impg/nhz2XSJLeRAh08aGlc73auLtJmamXAh8bhOo1g/OxiKB_m81O4.jpg?size=320x224&quality=96&sign=e487a06fa416f0e2a65c8b3e23b41cff&c_uniq_tag=gOmvu7F9lDkpdIaRJLwsZrU8x3yffrRpDdkp7edc02s&type=album',
#                                                                'width': 320},
#                                                               {'height': 357,
#                                                                'type': 'r',
#                                                                'url': 'https://sun1-57.userapi.com/impg/nhz2XSJLeRAh08aGlc73auLtJmamXAh8bhOo1g/OxiKB_m81O4.jpg?size=510x357&quality=96&sign=acd95b3c3fe77303068024ce3127421a&c_uniq_tag=q8nS38yhEDn18CwUb_6qsc-Wc7PxukhkRJblGBVnLbE&type=album',
#                                                                'width': 510},
#                                                               {'height': 52,
#                                                                'type': 's',
#                                                                'url': 'https://sun1-57.userapi.com/impg/nhz2XSJLeRAh08aGlc73auLtJmamXAh8bhOo1g/OxiKB_m81O4.jpg?size=75x52&quality=96&sign=4cccd7b2e35c19bc769ebec3a821cd23&c_uniq_tag=WzukxcVt3CcuYN_gxQPfDtkdV1v24b-CwAGlvQSiE4Y&type=album',
#                                                                'width': 75},
#                                                               {'height': 423,
#                                                                'type': 'x',
#                                                                'url': 'https://sun1-57.userapi.com/impg/nhz2XSJLeRAh08aGlc73auLtJmamXAh8bhOo1g/OxiKB_m81O4.jpg?size=604x423&quality=96&sign=f02132ffd2800bad658eb7c2d022fb50&c_uniq_tag=ChNroIqdv2IKAf3skrGkVQV_-46N5p19swdozLqwDIk&type=album',
#                                                                'width': 604},
#                                                               {'height': 565,
#                                                                'type': 'y',
#                                                                'url': 'https://sun1-57.userapi.com/impg/nhz2XSJLeRAh08aGlc73auLtJmamXAh8bhOo1g/OxiKB_m81O4.jpg?size=807x565&quality=96&sign=ded163a3383a7025086115dac9c154db&c_uniq_tag=1m1k6gMai3vsxFltDpphP9ZRSMWScuUhiQnnXxGUdbQ&type=album',
#                                                                'width': 807},
#                                                               {'height': 700,
#                                                                'type': 'z',
#                                                                'url': 'https://sun1-57.userapi.com/impg/nhz2XSJLeRAh08aGlc73auLtJmamXAh8bhOo1g/OxiKB_m81O4.jpg?size=1000x700&quality=96&sign=b7eb6ba6bafe764a6058cf28058ef257&c_uniq_tag=eqcsLyM-szRSQHfDxIJvb9hKQA5pB8m6UpfNARYkpBA&type=album',
#                                                                'width': 1000}],
#                                                     'text': '',
#                                                     'user_id': 100},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 1578,
#                                       'groups_can_post': True},
#                          'date': 1642084584,
#                          'edited': 1642084594,
#                          'from_id': -22822305,
#                          'hash': 'aQadgZJsnguQbKdVjA',
#                          'id': 1270492,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 3261,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'platform': 'iphone', 'type': 'api'},
#                          'post_type': 'post',
#                          'reposts': {'count': 2004, 'user_reposted': 0},
#                          'text': '[https://vk.com/checkback#snowfall|«Снегопад '
#                                  'подарков»] осыпал участников призами во '
#                                  'второй раз 🏆\n'
#                                  '\n'
#                                  'Заходите в мини-приложение: если вам '
#                                  'улыбнулась удача, увидите свой уникальный '
#                                  'номер в блоке «Победители». Мы заботимся о '
#                                  'личных границах и безопасности участников: в '
#                                  'списке нет фамилий, фото и ссылок на '
#                                  'профили. Но будем рады, если призёры '
#                                  'поделятся своими победами прямо в '
#                                  'комментариях!\n'
#                                  '\n'
#                                  'Со всеми победителями свяжемся в личных '
#                                  'сообщениях в течение суток и расскажем, как '
#                                  'получить подарки. Не волнуйтесь, если вам '
#                                  'ещё не написали: мы уже рядом 😉\n'
#                                  '\n'
#                                  'Но на этом вихрь сюрпризов не заканчивается '
#                                  '— продолжайте получать моментальные призы в '
#                                  '«Снегопаде подарков» до 15 января. А ещё на '
#                                  'следующей неделе объявим результаты '
#                                  'розыгрыша от банка ПСБ. Если собирали '
#                                  'специальные снежинки, следите за новостями!',
#                          'views': {'count': 1048634}},
#                         {'comments': {'can_post': 1,
#                                       'count': 614,
#                                       'groups_can_post': True},
#                          'copy_history': [{'attachments': [{'photo': {'access_key': 'e0580a0785dcd3b144',
#                                                                       'album_id': -7,
#                                                                       'date': 1640979953,
#                                                                       'id': 457240050,
#                                                                       'owner_id': 92933,
#                                                                       'post_id': 393,
#                                                                       'sizes': [{'height': 100,
#                                                                                  'type': 'm',
#                                                                                  'url': 'https://sun1-54.userapi.com/impg/s2poyM4I19SIIiU4CmTsVJhfkBccParKSsAY0Q/a7109yDzVL4.jpg?size=130x100&quality=96&sign=bf910d75c400f22eac9d3be88f7b1da9&c_uniq_tag=-n5hJvI5qaEkC0hnxTTaAipo8vlqSrIZiyeV5ca5Dgs&type=album',
#                                                                                  'width': 130},
#                                                                                 {'height': 100,
#                                                                                  'type': 'o',
#                                                                                  'url': 'https://sun1-54.userapi.com/impg/s2poyM4I19SIIiU4CmTsVJhfkBccParKSsAY0Q/a7109yDzVL4.jpg?size=130x100&quality=96&sign=bf910d75c400f22eac9d3be88f7b1da9&c_uniq_tag=-n5hJvI5qaEkC0hnxTTaAipo8vlqSrIZiyeV5ca5Dgs&type=album',
#                                                                                  'width': 130},
#                                                                                 {'height': 154,
#                                                                                  'type': 'p',
#                                                                                  'url': 'https://sun1-54.userapi.com/impg/s2poyM4I19SIIiU4CmTsVJhfkBccParKSsAY0Q/a7109yDzVL4.jpg?size=200x154&quality=96&sign=2bd8efc101b3995dce3b8ff05e32fbbb&c_uniq_tag=SAP0UE4RWGNk2D05HIXv0uOkpUYzjMqCY1XjpvMyKz4&type=album',
#                                                                                  'width': 200},
#                                                                                 {'height': 246,
#                                                                                  'type': 'q',
#                                                                                  'url': 'https://sun1-54.userapi.com/impg/s2poyM4I19SIIiU4CmTsVJhfkBccParKSsAY0Q/a7109yDzVL4.jpg?size=320x246&quality=96&sign=65d7028b62849631eb63726c51f52fab&c_uniq_tag=EuWJWD9X_NWlYLxysEHom_KTV4C_vgrB8IvYHSgcLNc&type=album',
#                                                                                  'width': 320},
#                                                                                 {'height': 392,
#                                                                                  'type': 'r',
#                                                                                  'url': 'https://sun1-54.userapi.com/impg/s2poyM4I19SIIiU4CmTsVJhfkBccParKSsAY0Q/a7109yDzVL4.jpg?size=510x393&quality=96&sign=b982cef8e49a924989a7b90c5900c8f0&c_uniq_tag=vF3PiAEl7E2ahMFo0cby9KuHakWakuJEvlZ-lMRSrrI&type=album',
#                                                                                  'width': 510},
#                                                                                 {'height': 58,
#                                                                                  'type': 's',
#                                                                                  'url': 'https://sun1-54.userapi.com/impg/s2poyM4I19SIIiU4CmTsVJhfkBccParKSsAY0Q/a7109yDzVL4.jpg?size=75x58&quality=96&sign=24f2dd38d986685a2423c805fe1c9d42&c_uniq_tag=vWJzwIVASe-sLkZFlHdVDSmnYTi4QwZ80tnlqy7p7kE&type=album',
#                                                                                  'width': 75},
#                                                                                 {'height': 1971,
#                                                                                  'type': 'w',
#                                                                                  'url': 'https://sun1-54.userapi.com/impg/s2poyM4I19SIIiU4CmTsVJhfkBccParKSsAY0Q/a7109yDzVL4.jpg?size=2560x1971&quality=96&sign=89d77e82dc8d640adab3828ab1d3c0d8&c_uniq_tag=EAwaMBDLyGMQoHbX7uPhv_fkFdB5dgN2olQrC6uomGk&type=album',
#                                                                                  'width': 2560},
#                                                                                 {'height': 465,
#                                                                                  'type': 'x',
#                                                                                  'url': 'https://sun1-54.userapi.com/impg/s2poyM4I19SIIiU4CmTsVJhfkBccParKSsAY0Q/a7109yDzVL4.jpg?size=604x465&quality=96&sign=9461b22f299d9ca76c5241d0a47b595c&c_uniq_tag=mrbBtsFub2EioTFqnJfTdaDdhml1OMemt71ENPm-LSo&type=album',
#                                                                                  'width': 604},
#                                                                                 {'height': 621,
#                                                                                  'type': 'y',
#                                                                                  'url': 'https://sun1-54.userapi.com/impg/s2poyM4I19SIIiU4CmTsVJhfkBccParKSsAY0Q/a7109yDzVL4.jpg?size=807x621&quality=96&sign=23b680268e975655eac2c5c6469813e1&c_uniq_tag=0KcWpJmu-NJTLWUcpkKQUUxV8-BfI2_29ozTwBIMtfw&type=album',
#                                                                                  'width': 807},
#                                                                                 {'height': 985,
#                                                                                  'type': 'z',
#                                                                                  'url': 'https://sun1-54.userapi.com/impg/s2poyM4I19SIIiU4CmTsVJhfkBccParKSsAY0Q/a7109yDzVL4.jpg?size=1280x985&quality=96&sign=e4cce48fae5907072657b4130b7f4ef0&c_uniq_tag=aMi6fc2J09QxpURIBk3zVaSl9YboKQhoME5WfvJWksk&type=album',
#                                                                                  'width': 1280}],
#                                                                       'text': ''},
#                                                             'type': 'photo'}],
#                                            'date': 1640980164,
#                                            'from_id': 92933,
#                                            'id': 393,
#                                            'owner_id': 92933,
#                                            'post_source': {'type': 'vk'},
#                                            'post_type': 'post',
#                                            'text': 'Команда ВКонтакте — люди, '
#                                                    'которые искренне '
#                                                    'восхищают. В этом году мы '
#                                                    'сделали рекордное число '
#                                                    'технологических прорывов и '
#                                                    'продуктовых обновлений за '
#                                                    'всю историю социальной '
#                                                    'сети. \n'
#                                                    '\n'
#                                                    'В уходящем 2021-м мы не '
#                                                    'только отметили 15-летие '
#                                                    'ВКонтакте и громко '
#                                                    'обновились на iPad, но и '
#                                                    'представили больше 230 '
#                                                    'крупных нововведений — в '
#                                                    'том числе неограниченные '
#                                                    'по числу участников VK '
#                                                    'Звонки, масштабную '
#                                                    'библиотеку контента и '
#                                                    'новые технологии платформы '
#                                                    'VK Видео, новые '
#                                                    'рекомендации Клипов, VK '
#                                                    'Музыки, представили новые '
#                                                    'алгоритмы Ленты Новостей и '
#                                                    'Рекомендаций, редизайн '
#                                                    'вкладки «Сервисы» (VK '
#                                                    'SuperApp), огромное число '
#                                                    'обновлений в мессенджере, '
#                                                    'одними из первых в мире '
#                                                    'технологию ускорение '
#                                                    'работы ВКонтакте по '
#                                                    'протоколу QUIC, а также '
#                                                    'автоматические переводы и '
#                                                    'автосубтитры в видео, '
#                                                    'новые AR-механики и многое '
#                                                    'другое. \n'
#                                                    '\n'
#                                                    'Год оказался настолько '
#                                                    'богат событиями, что мы '
#                                                    'рассказываем о них в '
#                                                    'течение всего декабря — в '
#                                                    'специальном разделе с '
#                                                    'итогами года ВКонтакте: '
#                                                    'vk.com/2021. \n'
#                                                    '\n'
#                                                    'Все эти достижения '
#                                                    'возможны только благодаря '
#                                                    'увлечённой работе нашей '
#                                                    'команды, которая вот уже '
#                                                    '15 лет бьёт все возможные '
#                                                    'рекорды и не собирается '
#                                                    'останавливаться в 2022 '
#                                                    'году, а также благодаря '
#                                                    'высочайшему интересу к '
#                                                    'нашим продуктам десятков '
#                                                    'миллионов людей из разных '
#                                                    'городов и стран. Работать '
#                                                    'над таким культовым '
#                                                    'проектом — настоящая '
#                                                    'мечта. Каждое обновление '
#                                                    'мы внедряем с желанием '
#                                                    'сделать наши продукты ещё '
#                                                    'удобнее, ещё технологичнее '
#                                                    'и интереснее, внимательно '
#                                                    'изучая востребованность '
#                                                    'сервисов и ваши отзывы. \n'
#                                                    '\n'
#                                                    'С наступающим Новым Годом, '
#                                                    'мечтайте, верьте, дерзайте '
#                                                    'и пусть все мечты '
#                                                    'сбываются! Вместе с '
#                                                    'ВКонтакте 💙'}],
#                          'date': 1640980531,
#                          'from_id': -22822305,
#                          'hash': '_tpp7CfTRb0tVrqQMQ',
#                          'id': 1268470,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 1678,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'platform': 'iphone', 'type': 'api'},
#                          'post_type': 'post',
#                          'reposts': {'count': 115, 'user_reposted': 0},
#                          'text': '',
#                          'views': {'count': 563013}},
#                         {'attachments': [{'type': 'video',
#                                           'video': {'access_key': 'cf76d1014d401c66ab',
#                                                     'can_add': 1,
#                                                     'can_add_to_faves': 1,
#                                                     'can_comment': 0,
#                                                     'can_like': 1,
#                                                     'can_repost': 1,
#                                                     'can_subscribe': 1,
#                                                     'comments': 95494,
#                                                     'date': 1641043804,
#                                                     'description': '',
#                                                     'duration': 12858,
#                                                     'first_frame_1280': 'https://i.mycdn.me/getVideoPreview?id=2107581729369&idx=0&type=39&tkn=jg7rc07GkO-yr4XvnbH15sH7hdY',
#                                                     'first_frame_130': 'https://i.mycdn.me/getVideoPreview?id=2107581729369&idx=0&type=35&tkn=fe6bAJMakST7rZ0igabuCgoK8Lw',
#                                                     'first_frame_160': 'https://i.mycdn.me/getVideoPreview?id=2107581729369&idx=0&type=34&tkn=avpEDd0nBuo_na6DAmjT7XB312Y',
#                                                     'first_frame_320': 'https://i.mycdn.me/getVideoPreview?id=2107581729369&idx=0&type=33&tkn=52xQzecWJl8t2KYklcDbtKdzBIk',
#                                                     'first_frame_800': 'https://i.mycdn.me/getVideoPreview?id=2107581729369&idx=0&type=32&tkn=Jb_aZgC8k9I5OH21y3-TVBtREd0',
#                                                     'height': 1080,
#                                                     'id': 456239379,
#                                                     'live_status': 'finished',
#                                                     'ov_id': '3323801906137',
#                                                     'owner_id': -22079806,
#                                                     'photo_1280': 'https://sun1-93.userapi.com/impf/1kxOGJTG2u0Prb6qKzae1gP9YHi9afDCaxuCAg/bLVREvv_1HM.jpg?size=1280x718&quality=96&sign=131894ebd0dd0268d67d94792225671f&c_uniq_tag=Nt4MeVuJga1b9zxU0Z6NXlrBssEjB9kkwLh6hAQl1NI&type=video_thumb',
#                                                     'photo_130': 'https://sun1-93.userapi.com/impf/1kxOGJTG2u0Prb6qKzae1gP9YHi9afDCaxuCAg/bLVREvv_1HM.jpg?size=130x96&quality=96&keep_aspect_ratio=1&background=000000&sign=ddee9fba1587855ee9c8eae5c6119e68&c_uniq_tag=EZ1qYV1DVMkg98PEONrKVY4daQz4Pu-0hjlrr6iD570&type=video_thumb',
#                                                     'photo_320': 'https://sun1-93.userapi.com/impf/1kxOGJTG2u0Prb6qKzae1gP9YHi9afDCaxuCAg/bLVREvv_1HM.jpg?size=320x240&quality=96&keep_aspect_ratio=1&background=000000&sign=bcdced4c259861edf8b087fabda92e1c&c_uniq_tag=lpjCWf3kBvaofoCLCIZQuInAVHrn9ejfG1dVEhYEoeg&type=video_thumb',
#                                                     'photo_800': 'https://sun1-93.userapi.com/impf/1kxOGJTG2u0Prb6qKzae1gP9YHi9afDCaxuCAg/bLVREvv_1HM.jpg?size=800x450&quality=96&keep_aspect_ratio=1&background=000000&sign=5da76d602d9d1339ebbd5ee203f162be&c_uniq_tag=X3lS5ljQxKsJDf6T1CuDkIjxaXdAo0g1luwDZY5fujw&type=video_thumb',
#                                                     'title': 'STAR Трек. Новый '
#                                                              'год ВКонтакте',
#                                                     'track_code': 'video_d01b23d2DWK87ReyYJI7GRQaWWpIHAM0dfTB6ZjNuhJ8rp5vqFU9Q6LvEN1mmTUREXFcX34uMA1Gw_jt76zWfnw',
#                                                     'views': 51019248,
#                                                     'width': 1920}}],
#                          'comments': {'can_post': 1,
#                                       'count': 112,
#                                       'groups_can_post': True},
#                          'date': 1640940328,
#                          'from_id': -22822305,
#                          'hash': 'ufcN7LD4igcNZ5_QGQ',
#                          'id': 1268341,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 2599,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 1531, 'user_reposted': 0},
#                          'text': 'Запускаем собственное шоу в первый вечер '
#                                  '2022-го! Смотрите онлайн-концерт «STAR Трек. '
#                                  'Новый год ВКонтакте» 1 января в 17:00 по '
#                                  'Москве.\n'
#                                  '\n'
#                                  'Мы собрали звёзд, блогеров и даже '
#                                  'космонавтов, чтобы поздравить вас. В '
#                                  'программе — [club21125731|HammAli & Navai], '
#                                  '[https://vk.com/esmireall|ESMI], '
#                                  '[club83040434|Big Baby Tape] и '
#                                  '[club95785182|Constantine], а также '
#                                  '[club5719309|«Руки Вверх!»] и '
#                                  '[club21354|«Ленинград»]. Кстати, Сергей '
#                                  'Шнуров представит новый проект «Зоя» — не '
#                                  'пропустите.\n'
#                                  '\n'
#                                  'Москвичам особенно повезло: шоу можно будет '
#                                  'посмотреть на фасадах кинотеатра «Октябрь» и '
#                                  'гостиницы «Космос», а также на Таганской '
#                                  'площади. Заходите в сообщество '
#                                  '[club22079806|«Официальные страницы '
#                                  'ВКонтакте»] и встречайте год по-звёздному '
#                                  'вместе с нами 💫\n'
#                                  '#новыйгодВКонтакте',
#                          'views': {'count': 592656}},
#                         {'attachments': [{'photo': {'access_key': '0dea4fdce41082054b',
#                                                     'album_id': -7,
#                                                     'date': 1640867644,
#                                                     'id': 457327190,
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1267875,
#                                                     'sizes': [{'height': 91,
#                                                                'type': 'm',
#                                                                'url': 'https://sun1-83.userapi.com/impg/SFfR2SI-RVPto51Qe_lV6BCvdcS5BHlgQkgDsQ/wODjEdZOfKM.jpg?size=130x91&quality=96&sign=b1d3a81dd44b9a5b90797cd26573ddda&c_uniq_tag=FmFeBDIburh3jUEYTz6CvLUTI3yyUkQj_XG3ZTtcQdY&type=album',
#                                                                'width': 130},
#                                                               {'height': 91,
#                                                                'type': 'o',
#                                                                'url': 'https://sun1-83.userapi.com/impg/SFfR2SI-RVPto51Qe_lV6BCvdcS5BHlgQkgDsQ/wODjEdZOfKM.jpg?size=130x91&quality=96&sign=b1d3a81dd44b9a5b90797cd26573ddda&c_uniq_tag=FmFeBDIburh3jUEYTz6CvLUTI3yyUkQj_XG3ZTtcQdY&type=album',
#                                                                'width': 130},
#                                                               {'height': 140,
#                                                                'type': 'p',
#                                                                'url': 'https://sun1-83.userapi.com/impg/SFfR2SI-RVPto51Qe_lV6BCvdcS5BHlgQkgDsQ/wODjEdZOfKM.jpg?size=200x140&quality=96&sign=4c55c4105704a11d0cea1a5ce4985829&c_uniq_tag=YwoWdYbXBJBokjpvT7clTh5x1SvMskZY9T295-1HZto&type=album',
#                                                                'width': 200},
#                                                               {'height': 224,
#                                                                'type': 'q',
#                                                                'url': 'https://sun1-83.userapi.com/impg/SFfR2SI-RVPto51Qe_lV6BCvdcS5BHlgQkgDsQ/wODjEdZOfKM.jpg?size=320x224&quality=96&sign=4d06d42dea520e3bc167ed23c732f331&c_uniq_tag=60lEEJ1-XrhIpMjOWnO3GPfihFFS25vuyD69iX5HUv0&type=album',
#                                                                'width': 320},
#                                                               {'height': 357,
#                                                                'type': 'r',
#                                                                'url': 'https://sun1-83.userapi.com/impg/SFfR2SI-RVPto51Qe_lV6BCvdcS5BHlgQkgDsQ/wODjEdZOfKM.jpg?size=510x357&quality=96&sign=30006bc7252be2611dd7798eea9f6e47&c_uniq_tag=4obaLcK_muO8VNrXj9smwjlbHpSaZGDS_aEyJae91PI&type=album',
#                                                                'width': 510},
#                                                               {'height': 52,
#                                                                'type': 's',
#                                                                'url': 'https://sun1-83.userapi.com/impg/SFfR2SI-RVPto51Qe_lV6BCvdcS5BHlgQkgDsQ/wODjEdZOfKM.jpg?size=75x52&quality=96&sign=630c70921ee97df4babd8c8382a0795a&c_uniq_tag=8Jf6CdO_G6lIzuJ-_tqkJiyrsYaXjODHi5jk4noKtsk&type=album',
#                                                                'width': 75},
#                                                               {'height': 423,
#                                                                'type': 'x',
#                                                                'url': 'https://sun1-83.userapi.com/impg/SFfR2SI-RVPto51Qe_lV6BCvdcS5BHlgQkgDsQ/wODjEdZOfKM.jpg?size=604x423&quality=96&sign=af175cbf80d948a854996ca515803a7c&c_uniq_tag=TxvUtJi7Iqbs-uqTUXmOIA3VW4AxW2KLKoNE1mEACYw&type=album',
#                                                                'width': 604},
#                                                               {'height': 565,
# ...
#                          'text': 'Команда ВКонтакте — это в первую очередь '
#                                  'люди. Каждый из нас — уникальный человек со '
#                                  'своей историей. Мы запускаем серию роликов '
#                                  '«Мой профиль», чтобы поделиться нашими '
#                                  'историями. \n'
#                                  '\n'
#                                  'Герой первого выпуска — iOS-разработчик и '
#                                  'создатель интерактивного шоу «Клевер» '
#                                  '[id242670751|Кирилл Аверьянов]. Ему всего '
#                                  '18, но он уже попал в список номинантов '
#                                  'рейтинга самых перспективных россиян моложе '
#                                  '30 по версии Forbes.\n'
#                                  '\n'
#                                  'Новые эпизоды проекта «Мой профиль» будут '
#                                  'выходить в сообществе [club147415323|VK '
#                                  'Tech]. Смотрите и знакомьтесь с нашей '
#                                  'Командой!',
#                          'views': {'count': 891508}},
#                         {'attachments': [{'photo': {'access_key': '29ac0a6a0142f7f0b8',
#                                                     'album_id': -7,
#                                                     'date': 1559899880,
#                                                     'id': 456299711,
#                                                     'owner_id': -22822305,
#                                                     'post_id': 902923,
#                                                     'sizes': [{'height': 89,
#                                                                'type': 'm',
#                                                                'url': 'https://sun1-21.userapi.com/impf/c850020/v850020403/1a6769/GTPSgjh2_Zc.jpg?size=130x89&quality=96&sign=43263ee4d61fe4d91a8bc5caa0961a8f&c_uniq_tag=AODNwQ7_6IFHuKsAOrVUgbYGskNkDOftBRs1qTWU0qs&type=album',
#                                                                'width': 130},
#                                                               {'height': 89,
#                                                                'type': 'o',
#                                                                'url': 'https://sun1-21.userapi.com/impf/c850020/v850020403/1a6769/GTPSgjh2_Zc.jpg?size=130x89&quality=96&sign=43263ee4d61fe4d91a8bc5caa0961a8f&c_uniq_tag=AODNwQ7_6IFHuKsAOrVUgbYGskNkDOftBRs1qTWU0qs&type=album',
#                                                                'width': 130},
#                                                               {'height': 138,
#                                                                'type': 'p',
#                                                                'url': 'https://sun1-21.userapi.com/impf/c850020/v850020403/1a6769/GTPSgjh2_Zc.jpg?size=200x137&quality=96&sign=8d8e12625aa14a990b7e92d126108546&c_uniq_tag=RQ5R_69ISQfiEtyrTrBgnsZvkqeBmOyz4wSGaW2F8_c&type=album',
#                                                                'width': 200},
#                                                               {'height': 220,
#                                                                'type': 'q',
#                                                                'url': 'https://sun1-21.userapi.com/impf/c850020/v850020403/1a6769/GTPSgjh2_Zc.jpg?size=320x220&quality=96&sign=4bdebdf36d7ed4e764d5f983182966ae&c_uniq_tag=kJkWwmC2Sh05xWl1wDeBc1cbPpHEnlyBUdgLjzAM8Gc&type=album',
#                                                                'width': 320},
#                                                               {'height': 351,
#                                                                'type': 'r',
#                                                                'url': 'https://sun1-21.userapi.com/impf/c850020/v850020403/1a6769/GTPSgjh2_Zc.jpg?size=510x351&quality=96&sign=502ce1fabeb15931a8793cdeb89e08d3&c_uniq_tag=hHvKCZ985pvq4wMZHj1ya0GxBxfF50G1BSf02MEwTeY&type=album',
#                                                                'width': 510},
#                                                               {'height': 51,
#                                                                'type': 's',
#                                                                'url': 'https://sun1-21.userapi.com/impf/c850020/v850020403/1a6769/GTPSgjh2_Zc.jpg?size=75x52&quality=96&sign=54866af76082e2532b97a588df8d8fc7&c_uniq_tag=GCq9hf4iqRA9BqkeyvJ1e4qTerWlRCM_g-_I3j0Fpuo&type=album',
#                                                                'width': 75},
#                                                               {'height': 1760,
#                                                                'type': 'w',
#                                                                'url': 'https://sun1-21.userapi.com/impf/c850020/v850020403/1a6769/GTPSgjh2_Zc.jpg?size=2560x1760&quality=96&sign=f49932e0b075fb906e7c1d4d0d6ec8da&c_uniq_tag=9eDaZpMyYPy2bT93tb7VVC_QqKsUwcMyKOZ98SYODjQ&type=album',
#                                                                'width': 2560},
#                                                               {'height': 415,
#                                                                'type': 'x',
#                                                                'url': 'https://sun1-21.userapi.com/impf/c850020/v850020403/1a6769/GTPSgjh2_Zc.jpg?size=604x415&quality=96&sign=3ae896290ea40be14bd725c244435222&c_uniq_tag=2Xabat7J9M3fmqzlrg9ARvfBSs2wloUWjAHmImmZuLk&type=album',
#                                                                'width': 604},
#                                                               {'height': 555,
#                                                                'type': 'y',
#                                                                'url': 'https://sun1-21.userapi.com/impf/c850020/v850020403/1a6769/GTPSgjh2_Zc.jpg?size=807x555&quality=96&sign=1a4fca24baf645c038372e6e17a4ce97&c_uniq_tag=XGi4YyT5rwjNEx9FJkioNgGrOHJXeXEzlf-vkVIjXqo&type=album',
#                                                                'width': 807},
#                                                               {'height': 880,
#                                                                'type': 'z',
#                                                                'url': 'https://sun1-21.userapi.com/impf/c850020/v850020403/1a6769/GTPSgjh2_Zc.jpg?size=1280x880&quality=96&sign=0c812630204ec0076bed76df5ec6d208&c_uniq_tag=qnlnL9MAUxXb9eDfS0fBueQLo0F8yqpWxuBKpmOLg4c&type=album',
#                                                                'width': 1280}],
#                                                     'text': '',
#                                                     'user_id': 100},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 4828,
#                                       'groups_can_post': True},
#                          'date': 1559906833,
#                          'from_id': -22822305,
#                          'hash': 'E5YuDxypFKXbOsHanw',
#                          'id': 902923,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 5410,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 393, 'user_reposted': 0},
#                          'text': 'Попробуйте обновлённый раздел «Видео» в '
#                                  'мобильном приложении! Система рекомендаций '
#                                  'подберёт материалы специально для Вас, '
#                                  'подборки лучших роликов помогут следить за '
#                                  'трендами, а тематические категории позволят '
#                                  'с головой окунаться в любимую тему.\n'
#                                  '\n'
#                                  'Сейчас нововведение находится в стадии '
#                                  'тестирования. Со временем рекомендации '
#                                  'станут точнее, а общее качество материалов — '
#                                  'выше. О новых вкладках раздела, а также о '
#                                  'функциях, которые сделают просмотр удобнее, '
#                                  'читайте в статье: '
#                                  'vk.com/@team-meet-the-video',
#                          'views': {'count': 1175249}},
#                         {'attachments': [{'photo': {'access_key': 'e32b7c3a65a479e709',
#                                                     'album_id': -7,
#                                                     'date': 1556187433,
#                                                     'id': 456298627,
#                                                     'owner_id': -22822305,
#                                                     'post_id': 829273,
#                                                     'sizes': [{'height': 87,
#                                                                'type': 'm',
#                                                                'url': 'https://sun1-26.userapi.com/impf/Jn0Y9LzE3UG-jJ4UlufyPj4oLoUldSJwT9GE_Q/z6-PNE8amX0.jpg?size=130x87&quality=96&sign=099241e8dd5fa42db61c33be35b9693a&c_uniq_tag=9Nbzb73FQO3cErEVduP-zUsErqo5Ei9350maqsccWnI&type=album',
#                                                                'width': 130},
#                                                               {'height': 87,
#                                                                'type': 'o',
#                                                                'url': 'https://sun1-26.userapi.com/impf/Jn0Y9LzE3UG-jJ4UlufyPj4oLoUldSJwT9GE_Q/z6-PNE8amX0.jpg?size=130x87&quality=96&sign=099241e8dd5fa42db61c33be35b9693a&c_uniq_tag=9Nbzb73FQO3cErEVduP-zUsErqo5Ei9350maqsccWnI&type=album',
#                                                                'width': 130},
#                                                               {'height': 133,
#                                                                'type': 'p',
#                                                                'url': 'https://sun1-26.userapi.com/impf/Jn0Y9LzE3UG-jJ4UlufyPj4oLoUldSJwT9GE_Q/z6-PNE8amX0.jpg?size=200x133&quality=96&sign=d4f0ca5039fc3ff570deaeec0b71a92d&c_uniq_tag=fPbzxpfQVgVPKbtgSwdfwXkOQxCQOozPo5Jpx649Zac&type=album',
#                                                                'width': 200},
#                                                               {'height': 213,
#                                                                'type': 'q',
#                                                                'url': 'https://sun1-26.userapi.com/impf/Jn0Y9LzE3UG-jJ4UlufyPj4oLoUldSJwT9GE_Q/z6-PNE8amX0.jpg?size=320x213&quality=96&sign=59a40e15ba10843d103a43033444e7ae&c_uniq_tag=jni8YZFgJX7zmox2ylPV694ctkXLZHfa2vmJSFQTVaE&type=album',
#                                                                'width': 320},
#                                                               {'height': 340,
#                                                                'type': 'r',
#                                                                'url': 'https://sun1-26.userapi.com/impf/Jn0Y9LzE3UG-jJ4UlufyPj4oLoUldSJwT9GE_Q/z6-PNE8amX0.jpg?size=510x340&quality=96&sign=2612489d25928247f154a71140e71287&c_uniq_tag=7b7dMZHrOeb-FH850jjFlFKnhBXVvqOxXkIUm4V2lJI&type=album',
#                                                                'width': 510},
#                                                               {'height': 50,
#                                                                'type': 's',
#                                                                'url': 'https://sun1-26.userapi.com/impf/Jn0Y9LzE3UG-jJ4UlufyPj4oLoUldSJwT9GE_Q/z6-PNE8amX0.jpg?size=75x50&quality=96&sign=9f183537f32a95040c34a34db8109d46&c_uniq_tag=QRjEPoXfUhL08dThnzKmnTip367m8Wa8PnHMoj_Y1O4&type=album',
#                                                                'width': 75},
#                                                               {'height': 1479,
#                                                                'type': 'w',
#                                                                'url': 'https://sun1-26.userapi.com/impf/Jn0Y9LzE3UG-jJ4UlufyPj4oLoUldSJwT9GE_Q/z6-PNE8amX0.jpg?size=2218x1479&quality=96&sign=c31f3c2f4380d4b100871a037d866f7d&c_uniq_tag=3JRkhWgBHOFGcccAKfArJdSIPqIL3JZ5GXWvU2QTH88&type=album',
#                                                                'width': 2218},
#                                                               {'height': 403,
#                                                                'type': 'x',
#                                                                'url': 'https://sun1-26.userapi.com/impf/Jn0Y9LzE3UG-jJ4UlufyPj4oLoUldSJwT9GE_Q/z6-PNE8amX0.jpg?size=604x403&quality=96&sign=32e58110971348aaa99e8f9d6fce55e8&c_uniq_tag=2aM0VMvsDLXqNhkTVJM46DBqh40Ikmoe-ZbCaYQT82U&type=album',
#                                                                'width': 604},
#                                                               {'height': 538,
#                                                                'type': 'y',
#                                                                'url': 'https://sun1-26.userapi.com/impf/Jn0Y9LzE3UG-jJ4UlufyPj4oLoUldSJwT9GE_Q/z6-PNE8amX0.jpg?size=807x538&quality=96&sign=ca75ace32bc3e2954459d938556222ff&c_uniq_tag=vJBuRydoO3YSkhc-la4a72TbEiVJWLFiYcS_pxg3aqg&type=album',
#                                                                'width': 807},
#                                                               {'height': 854,
#                                                                'type': 'z',
#                                                                'url': 'https://sun1-26.userapi.com/impf/Jn0Y9LzE3UG-jJ4UlufyPj4oLoUldSJwT9GE_Q/z6-PNE8amX0.jpg?size=1280x854&quality=96&sign=413b219906b5e2931bf58c7986cbf648&c_uniq_tag=rCtwEDiIOPrIe9503UOLiFbsPFQOsZ164DxsX4YSEFA&type=album',
#                                                                'width': 1280}],
#                                                     'text': '',
#                                                     'user_id': 100},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 13929,
#                                       'groups_can_post': True},
#                          'date': 1556198345,
#                          'from_id': -22822305,
#                          'hash': 'w3oQ-qP2BG6OOQ68QA',
#                          'id': 829273,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 15279,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 1201, 'user_reposted': 0},
#                          'text': 'Мы создаём сервисы, которые соединяют людей, '
#                                  'помогают легко общаться с бизнесом и решать '
#                                  'повседневные вопросы. \n'
#                                  '\n'
#                                  'Рады поделиться новым рекордом: мы достигли '
#                                  'отметки в 10 000 000 000 сообщений в сутки!',
#                          'views': {'count': 3833551}}]}}

# %%
response.json()['response']['items'][0]
# Out:
# {'id': 1275041,
#  'from_id': -22822305,
#  'owner_id': -22822305,
#  'date': 1644840943,
#  'marked_as_ads': 0,
#  'post_type': 'post',
#  'text': 'День святого Валентина — повод показать свои чувства. Мы любим вас, поэтому подготовили праздничные сюрпризы. Приоткрываем шкатулку ✨ \n\n📌 Отправляйте послания любимым и друзьям: кидайте их в виртуальную [https://vk.com/app6851096|«Коробку для валентинок»]. Признания могут быть анонимными — адресат увидит ваше имя, только если тоже напишет вам. А ещё вы можете отправить валентинку в 2023-й — уже не скрывая чувств!\n\n📌 Ищете пару? Заглядывайте в [https://vk.com/dating|VK Знакомства]. Всего на один день некоторые премиум-функции стали бесплатными. Ставьте суперлайки, возвращайтесь к предыдущим профилям и смотрите анкеты тех, кто проявил к вам интерес. \n\n📌 А если хотите окунуться в романтику, почитайте истории влюблённых из [https://vk.com/youla_ru?w=wall-137839839_210399|Екатеринбурга] и [https://vk.com/vkclassifieds?w=wall-200241296_32397|Новосибирска]. Они познакомились, когда покупали и продавали товары в сервисах VK. Отношения могут начаться неожиданно. Вот она, магия любви ❤ \n\nИ это далеко не все сюрпризы. Обнимайтесь в [https://vk.com/calls|VK Звонках], украшайте чаты, слушайте праздничные плейлисты в [https://vk.com/music|VK Музыке]. А если вся эта атмосфера вам не по душе, разбивайте сердца в игре [https://vk.com/antivalentine|«Краш-тест»]. \n\n🥰 Подробнее обо всех активностях читайте в нашей новости: vk.com/press/valentines-day-2022',
#  'attachments': [{'type': 'photo',
#    'photo': {'album_id': -7,
#     'date': 1644840428,
#     'id': 457328227,
#     'owner_id': -22822305,
#     'access_key': '3c18beec62ab6b65d8',
#     'post_id': 1275041,
#     'sizes': [{'height': 55,
#       'url': 'https://sun1-24.userapi.com/impg/PpwsjqPy_lmiyZYjP6PmMYBVgTa9KbYIuFE_Jg/MKHiXZmygK4.jpg?size=75x55&quality=95&sign=7dbab22b23b223b6fba3f4c55d83593a&c_uniq_tag=gIFTj5PP7885O463Y5OUc-RDjxXB40VptvJyc4UH1b0&type=album',
#       'type': 's',
#       'width': 75},
#      {'height': 96,
#       'url': 'https://sun1-24.userapi.com/impg/PpwsjqPy_lmiyZYjP6PmMYBVgTa9KbYIuFE_Jg/MKHiXZmygK4.jpg?size=130x96&quality=95&sign=a003f57193eed24abecfd3269fce6ae7&c_uniq_tag=8iJDjHVOvLxrBHyp-RfUXvJeFIBZqZa1D5LPJ3_pRUc&type=album',
#       'type': 'm',
#       'width': 130},
#      {'height': 444,
#       'url': 'https://sun1-24.userapi.com/impg/PpwsjqPy_lmiyZYjP6PmMYBVgTa9KbYIuFE_Jg/MKHiXZmygK4.jpg?size=604x444&quality=95&sign=09c2b57b9b669df0c863f97d354c4f97&c_uniq_tag=0XN5IHAmSQH4WfTdPv_szCOOMJjOV30HAT3ZRvPOZIs&type=album',
#       'type': 'x',
#       'width': 604},
#      {'height': 593,
#       'url': 'https://sun1-24.userapi.com/impg/PpwsjqPy_lmiyZYjP6PmMYBVgTa9KbYIuFE_Jg/MKHiXZmygK4.jpg?size=807x593&quality=95&sign=fb9e08a380b4db34a188b30484ded3a1&c_uniq_tag=eePZchS-_wamLUJl3KU0VB5w5BhpKUO2K9l89dAXM2o&type=album',
#       'type': 'y',
#       'width': 807},
#      {'height': 941,
#       'url': 'https://sun1-24.userapi.com/impg/PpwsjqPy_lmiyZYjP6PmMYBVgTa9KbYIuFE_Jg/MKHiXZmygK4.jpg?size=1280x941&quality=95&sign=4e99e4184f3dcdf100b1e15ba27b51b4&c_uniq_tag=kx5qoVCGG_CTmjEho2X07REe9S2RL3V72SG7SEqUHoY&type=album',
#       'type': 'z',
#       'width': 1280},
#      {'height': 1470,
#       'url': 'https://sun1-24.userapi.com/impg/PpwsjqPy_lmiyZYjP6PmMYBVgTa9KbYIuFE_Jg/MKHiXZmygK4.jpg?size=2000x1470&quality=95&sign=8651d44462629bb95422998257ac4ee4&c_uniq_tag=tSp5HUVeuLfdpAydS1JFCGKWwu1cRIE40e40ZxtWBfI&type=album',
#       'type': 'w',
#       'width': 2000},
#      {'height': 96,
#       'url': 'https://sun1-24.userapi.com/impg/PpwsjqPy_lmiyZYjP6PmMYBVgTa9KbYIuFE_Jg/MKHiXZmygK4.jpg?size=130x96&quality=95&sign=a003f57193eed24abecfd3269fce6ae7&c_uniq_tag=8iJDjHVOvLxrBHyp-RfUXvJeFIBZqZa1D5LPJ3_pRUc&type=album',
#       'type': 'o',
#       'width': 130},
#      {'height': 147,
#       'url': 'https://sun1-24.userapi.com/impg/PpwsjqPy_lmiyZYjP6PmMYBVgTa9KbYIuFE_Jg/MKHiXZmygK4.jpg?size=200x147&quality=95&sign=75800d0f21be3e7106633acecf84f033&c_uniq_tag=9798UqagTbwkqIMoOJ8O_kBoYeP_KEu-ijTPbtAVPA4&type=album',
#       'type': 'p',
#       'width': 200},
#      {'height': 235,
#       'url': 'https://sun1-24.userapi.com/impg/PpwsjqPy_lmiyZYjP6PmMYBVgTa9KbYIuFE_Jg/MKHiXZmygK4.jpg?size=320x235&quality=95&sign=b0383bc288c1137b73117a704e1e6dbe&c_uniq_tag=FF44xOJfuTxCfPIUVbFuThRVkbzUBvb07t-FHWEymoM&type=album',
#       'type': 'q',
#       'width': 320},
#      {'height': 375,
#       'url': 'https://sun1-24.userapi.com/impg/PpwsjqPy_lmiyZYjP6PmMYBVgTa9KbYIuFE_Jg/MKHiXZmygK4.jpg?size=510x375&quality=95&sign=6613b1ca6f4ccb4d8067c72fc4510601&c_uniq_tag=yAIn8zkYbopeXxd8lLtaTFz45Q3bLIAkmZszF72s8DU&type=album',
#       'type': 'r',
#       'width': 510}],
#     'text': '',
#     'user_id': 100}}],
#  'post_source': {'type': 'vk'},
#  'comments': {'can_post': 1, 'count': 101, 'groups_can_post': True},
#  'likes': {'can_like': 1, 'count': 332, 'user_likes': 0, 'can_publish': 1},
#  'reposts': {'count': 106, 'user_reposted': 0},
#  'views': {'count': 108157},
#  'hash': 'smdsXYzsODJgyDArxw'}

# %% [markdown]
# Давайте соберём итоговую статистику для последних десяти непустых сообщений в словарь stats. В качестве ключа будем использовать начало сообщения (если начало сообщения пустое, то информацию о таком сообщении проигнорируем), в качестве значения — список с тремя интересующими нас метриками и временем публикации (комментарии, лайки, репосты, дата публикации):

# %%
stats = {} 
count_post = 0 # Счётчик «непустых» сообщений
for record in response.json()['response']['items'][:]:
    title = record['text'][:30] 
    if title: 
        stats[title] = [record['comments']['count'], record['likes']['count'], record['reposts']['count'], record['date']] 
        count_post += 1 
    if count_post < 10: 
        continue 
    else: 
        break 
pprint(stats)
# Out:
# {'[https://vk.com/checkback#snow': [1578, 3261, 2004, 1642084584],
#  'А если взглянуть в целом, то к': [278, 931, 266, 1640094467],
#  'ВКонтакте всегда есть что посм': [200, 948, 94, 1640017040],
#  'День святого Валентина — повод': [101, 332, 106, 1644840943],
#  'Запускаем собственное шоу в пе': [112, 2599, 1531, 1640940328],
#  'Каким был ваш 2021-й ВКонтакте': [606, 2265, 9785, 1640174402],
#  'Мы приготовили для вас целую г': [176, 4332, 668, 1640712137],
#  'Нейросети на страже высокого к': [561, 2846, 855, 1644258069],
#  'Объявляем итоги первого розыгр': [672, 2129, 972, 1640871560],
#  'Эти каникулы будут особенными ': [132, 1281, 163, 1640171709]}

# %% [markdown]
# СКРИПТЫ

# %% [markdown]
# КАК НАСТРОИТЬ АВТОМАТИЧЕСКИЙ ЗАПУСК

# %%
import schedule

def task(): 
    print('Hello! I am a task!') 
    return

schedule.every(1).minutes.do(task)

import time 
while True: 
    schedule.run_pending() 
    time.sleep(1)

# %% [markdown]
# Вам предоставлен словарь products, ключами которого являются названия продуктов, а значениями — их цены. Затем вы получаете другой словарь (stocks), ключи которого — товары, а значения — скидки (в процентах) на товары.
#
# Напишите функцию apply_discounts(), которая снижает цену продуктов в словаре products на указанный в словаре stocks процент. Функция должна вернуть результирующий словарь, ключи которого — товары, а значения — новые цены. Если продукта из словаря products нет в словаре stocks, то скидка к нему не применяется. Цены округлите до второго знака после запятой.

# %%
def apply_discounts(products, stocks):
    """
    Напишите функцию apply_discounts(), которая снижает цену продуктов в словаре products на указанный в словаре stocks процент. 
    Функция должна вернуть результирующий словарь, ключи которого — товары, а значения — новые цены.
    Если продукта из словаря stocks нет в словаре products, то его необходимо пропустить. Цены округлите до второго знака после запятой.
    """
    for prod, price in products.items():
        if prod in stocks.keys():
            products[prod] = round(price*(100 - int(stocks[prod][:-1]))/100, 2)
            print(int(stocks[prod][:-1]))
    return products

    
if __name__ == '__main__':
    products={
        "Oranges (packaged)": 114.99, 
        "Candy (Rotfront)": 280.00,
        "Boiled sausage": 199.99,
        "Juice J7 (orange)": 119.99,
        "Trout (Seven Seas)": 399.99
        }
    stocks = {
        "Boiled sausage": "33%",
        "Juice J7 (orange)": "12%",
        "Trout (Seven Seas)": "18%"
    }
    new_products = apply_discounts(products, stocks)
    print(new_products)

# %% [markdown]
# Вам даны два файла, bronze_top и silver_top (пути к ним заданы в Codeboard), в которых хранится информация о ТОП-5 стран по числу бронзовых и серебряных медалей соответственно. В каждой таблице два одинаковых столбца: Country — страна и Total — число медалей.
#
# Объедините две таблицы по странам таким образом, чтобы в результат вошли данные только о тех странах, которые попали в оба рейтинга. При этом в качестве суффиксов укажите строки "_bronze" и "_silver", чтобы столбцы таблиц, не участвовавших в объединении, можно было различать.
#
# Результат занесите в переменную merged.

# %%
import pandas as pd

bronze_path = './Root/data/bronze_top.csv'
silver_path = './Root/data/silver_top.csv'
"""
Объедините две таблицы по странам таким образом, чтобы в результат вошли данные только о тех странах, которые есть в обоих рейтингах. 
При этом в качестве суффиксов для столбца c числом медалей укажите строки "_bronze" и "_silver", чтобы столбцы можно было различать.
Результат занесите в переменную merged.
"""
bronze = pd.read_csv(bronze_path)
silver = pd.read_csv(silver_path)
#print(bronze.head())
#print(silver.head())

merged = bronze.merge(
    silver, 
    how='inner',
    on='Country',
    suffixes=('_bronze', '_silver')
    #lsuffix='_bronze',
    #rsuffix='_silver'
    )
print(merged)
